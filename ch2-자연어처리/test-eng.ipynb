# %% [markdown]
# # 영문 분석 -> 워드 클라우드로 그리기(시각화)
#
# ## 샘플 데이터 영문 학술 문서의 제목만 추출, 그 단어의 빈도 분석 시각화
# ## 데이터 수집 : Big data 키워드로 검색 후, 해당 학술 연구 정보 서비스에서 수집 해보기.
# ## 조합, pandas.concat(), 정제 re 정규식, 기본적인 유효성 체크.
# ## 변환 : word_tokenize(), lower(),
# ## matplotlib.pyplot 이용하기.
# ## 단어 빈도 구해주는 Counter() 이용.
#
# ## 비정형 빅데이터 분석을 말하고 -> 자연어 처리 (nature language processing )
# ## 자연어 처리 예) 음성, 텍스트 정보 추출.
#
# ## 단어 빈도를 추출해서, 해당 단어 시각화하기.

# %% [markdown]
# # 관련 단어 용어 정리
# ## 텍스트 분석: 자연어 처리와 데이터 마이닝 결합하여 발전되었고,
# ## 비정형 텍스트 데이터에서 정보를 추출하는 분석 방법.
# ## 분석 방법 : 1) 텍스트 분류 2) 텍스트 군집화 3) 감성 분석.
#
# ## 전처리 : 분석 작업의 정확도를 높이기 위해서 사용할 데이터 정리하고 변환하는 작업.
# ### 수행하는 작업
# ### 정제 (cleaning): 불필요한 기호, 문자 필터하는 작업, 정규식을 이용해서 작업을 함.
# ### 정규화 ( normallization) : 형태가 다른 단어를 특정의 형태로 변환 작업 , 대문자, 소문자 통합 하는 작업, 의미가 비슷한 단어끼리 통합작업.
# ### 토큰화 (tokenization) : 토큰으로 정하는 기본 단위로 분리 작업. 문장 기준, 단어 기준이 될수 도 있다.
# ### 불용어제거(stopword) : 의미 있는 단어를 추출하기 위해서, 조사, 관사, 접미사, 접두사 등. 제거하는 작업.
# ### 어간 추출(semming) : 단수, 복수, 진행형(시제), 분리하는 작업
# ### 표제어 추출(lemmatization ): 단어의 기본형 형태로 일반화 하는 작업.
# ### 예)
# ### Gone -> go
# ### am -> be
# ### going -> go
#
# ## 워드클라우드 : 텍스트 분석에서 빈도를 시각화 할 때 많이 사용됨.

# %% [markdown]
# # 데이터 수집
# # 한국교육학술정보원 (KERIS)의 RISS 사이트
# # https://www.riss.kr/index.do
# # Big data 검색해보기.
# # 한 페이지당 100개씩 내보내기 엑셀 파일 간략 정보 , 반복 10번
# # 1000개의 데이터에서 제목만 추출 및 분류 작업하기.

# %% [markdown]
# # 데이터 준비 작업.
# # 제목 컬럼 빈도 분석 해보기.

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# 2025-03-04 10:27:13.754 Python[3847:65848] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-04 10:27:13.755 Python[3847:65848] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# True

# %%
# 관련 패키지들 임포트 하기.
import pandas as pd
# 경로 이름 지정해서 파일 처리할 때 사용하는 도구
import glob
# 정규 표현식에 사용하는 도구
import re
# 2차원 리스트를 -> 1차원 리스트로 차원 축소시 사용하는 도구
from functools import reduce
# 자연어 처리 패키지 중에서, 단어 토큰화 작업.
from nltk.tokenize import word_tokenize
# 불용어 처리 작업.
from nltk.corpus import stopwords
# 표제어 추출
from nltk.stem import WordNetLemmatizer
# 단어의 빈도를 추출하는 도구.
from collections import Counter
import matplotlib.pyplot as plt
# 단어의 빈도수를 시각화하는 도구, 빈도가 높을수록 글자 크기가 커짐.
from wordcloud import STOPWORDS, WordCloud

# %%
# 데이터 조합(병합)하기. 
# 현재 폴더 내부에 있는 , 받았던 엑셀 파일명 10개를 선택하기. 
# all_files = glob.glob("./myCabinetExcelData*.xls")
all_files = glob.glob("./exportExcelData_*.xls")

# 엑셀 파일 읽어서 -> 데이터 프레임 (표형태) 변환 ->특정 리스트에 담아두기 
# 임시로 저장할 리스트 변수 
all_files_data = []

# all_files 에 담겨진 엑셀 파일의 위치가 들어있고, 
# 해당 위치의 엑셀 파일을 읽어서, 데이터 프레임 표 형태로 변환하기. 
# 임시 리스트에 담기. 
for file in all_files:
  # 해당 엑셀 파일의 위치의 물리 파일 읽기
  data_frame = pd.read_excel(file)
  # 임시 리스트에 담기. 
  all_files_data.append(data_frame)

# 샘플 확인 해보기., 첫번째 요소 확인 해보기. 
# all_files_data = [엑셀1,엑셀2,엑셀3,...엑셀10]
all_files_data[0]

# 오류 발생, 모듈 미설치 : xlrd
# cmd -> pip install xlrd
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1  Big Data Analysis With R-studio for Radioactiv...
# 1          NaN    2                                    Big Data Mining
# 2          NaN    3  Development of Big Data Platform Operation and...
# 3          NaN    4  Word Cloud Visualization and Semantics Using B...
# 4          NaN    5  Big Data Management System for Biomedical Imag...
# ..         ...  ...                                                ...
# 95         NaN   96  A Study on Big Data Analysis Related to ‘Digit...
# 96         NaN   97  Fault Detection of Plasma Etchers using Big Da...
# 97         NaN   98  A Case Study of Topic Modeling for Papers Rela...
# 98         NaN   99  A Study on Feasibility of Evaluating IT Projec...
# 99         NaN  100              설비 품질 Big Data 분석을 통한 선제적 품질 관리 체계 구축
#
#                      저자                                                출판사  \
# 0              Hyuk Han                                         한국방사성폐기물학회
# 1                   권미경                                           한국경영정보학회
# 2   곽재혁(Jae-Hyuck Kwak)  Korean Institute of Information Scientists and...
# 3      Soo-tai Nam(남수태)                                           한국정보통신학회
# 4        Shamweel Qamar                                       한국시스템엔지니어링학회
# ..                  ...                                                ...
# 95          Sung-ae Kim                                           한국정보통신학회
# 96              Wei Qin                                           한국생산제조학회
# 97       Dong Joon Park                                        한국산업경영시스템학회
# 98                  김홍삼                                        한국산업경영시스템학회
# 99                  남동균                                           한국품질경영학회
#
#      출판일
# 0   2021
# 1   2013
# 2   2020
# 3   2024
# 4   2019
# ..   ...
# 95  2022
# 96  2014
# 97  2020
# 98  2017
# 99  2019
#
# [100 rows x 6 columns]

# %%
# 엑셀 파일 10개를 병합해서 출력해보기. 
# axis=0 , 세로 방향으로 , 밑으로 데이터를 붙이는 작업. 
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)
print(f"all_files_data_concat.shape : {all_files_data_concat.shape}")

# 병합된 파일을 csv 파일로 변환하기. 
all_files_data_concat.to_csv("./riss_Bigdata_2025.csv", encoding="utf-8", index=False)
# Out:
# all_files_data_concat.shape : (1000, 6)

# %%
# 전처리 작업 하기. 
# 데이터 프레임에서 제목 열만 추출 
all_title = all_files_data_concat["제목"]

#불용어 제거 
# set(), 기본적으로 중복 제거

# NLTK(Natural Language Toolkit) 라이브러리의 stopwords 모듈에서
# 영어에 해당하는 불용어 리스트를 가져옵니다.
# 불용어는 "the", "is", "in" 등처럼 분석에 크게 기여하지 않는, 자주 등장하는 단어들을 의미합니다.
stopWords = set(stopwords.words("english"))

# lemma 작업 -> 표제어 추출, 영어, 시제를 제거하고, 원형(사전식 단어 추출)
lemma = WordNetLemmatizer()

# %%
# 임시로 담을 변수, 
words = []

# 기본적인 , 단어 추출(전처리 작업.)
for title in all_title:
  # 영문자, 대 소문자를 제외한 나머지 문자는 모두 공백으로 처리하겠다. 
  print(f"과정1 title 원본: {title}")
  enWords = re.sub(r"[^a-zA-Z]+"," ",str(title))
  print(f"과정2 title enWords(re: 대소문자남기기): {enWords}")
  # 남은 영문자를 -> 모두 소문자 변환하고 -> 각단어를 토큰으로 각각 분리 작업. 
  enWordsToken = word_tokenize(enWords.lower())
  print(f"과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): {enWordsToken}")
  # 컴프리헨션 파이썬 스타일 코드로 , 리스로 변경하기. 
  
  # 불용어 제거 작업, 조사, 관사 등 제거하는 작업. -> 오타:stopwords -> stopWords
  enWordsTokenStop= [w for w in enWordsToken if w not in stopWords]
  print(f"과정4 title enWordsTokenStop(불용어 제거): {enWordsTokenStop}")

  # 표제어 추출 작업. 
  enWordsTokenStopLemma = [lemma.lemmatize(w) for w in enWordsTokenStop]
  print(f"과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): {enWordsTokenStopLemma}")

  words.append(enWordsTokenStopLemma)
  
print(f"words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : {words}")
# Out:
# 과정1 title 원본: Big Data Analysis With R-studio for Radioactive Waste’s Concentration Behavior According to Data Components
# 과정2 title enWords(re: 대소문자남기기): Big Data Analysis With R studio for Radioactive Waste s Concentration Behavior According to Data Components
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis', 'with', 'r', 'studio', 'for', 'radioactive', 'waste', 's', 'concentration', 'behavior', 'according', 'to', 'data', 'components']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'r', 'studio', 'radioactive', 'waste', 'concentration', 'behavior', 'according', 'data', 'components']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'r', 'studio', 'radioactive', 'waste', 'concentration', 'behavior', 'according', 'data', 'component']
# 과정1 title 원본: Big Data Mining
# 과정2 title enWords(re: 대소문자남기기): Big Data Mining
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'mining']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'mining']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'mining']
# 과정1 title 원본: Development of Big Data Platform Operation and Management System Considering HPC Environments
# 과정2 title enWords(re: 대소문자남기기): Development of Big Data Platform Operation and Management System Considering HPC Environments
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['development', 'of', 'big', 'data', 'platform', 'operation', 'and', 'management', 'system', 'considering', 'hpc', 'environments']
# 과정4 title enWordsTokenStop(불용어 제거): ['development', 'big', 'data', 'platform', 'operation', 'management', 'system', 'considering', 'hpc', 'environments']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['development', 'big', 'data', 'platform', 'operation', 'management', 'system', 'considering', 'hpc', 'environment']
# 과정1 title 원본: Word Cloud Visualization and Semantics Using Big Data Analytics Tools
# 과정2 title enWords(re: 대소문자남기기): Word Cloud Visualization and Semantics Using Big Data Analytics Tools
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['word', 'cloud', 'visualization', 'and', 'semantics', 'using', 'big', 'data', 'analytics', 'tools']
# 과정4 title enWordsTokenStop(불용어 제거): ['word', 'cloud', 'visualization', 'semantics', 'using', 'big', 'data', 'analytics', 'tools']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['word', 'cloud', 'visualization', 'semantics', 'using', 'big', 'data', 'analytics', 'tool']
# 과정1 title 원본: Big Data Management System for Biomedical Images to Improve Short-term and Long-term Storage
# 과정2 title enWords(re: 대소문자남기기): Big Data Management System for Biomedical Images to Improve Short term and Long term Storage
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'management', 'system', 'for', 'biomedical', 'images', 'to', 'improve', 'short', 'term', 'and', 'long', 'term', 'storage']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'management', 'system', 'biomedical', 'images', 'improve', 'short', 'term', 'long', 'term', 'storage']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'management', 'system', 'biomedical', 'image', 'improve', 'short', 'term', 'long', 'term', 'storage']
# 과정1 title 원본: Big Data Geo Analysis for Ancient Historical Places
# 과정2 title enWords(re: 대소문자남기기): Big Data Geo Analysis for Ancient Historical Places
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'geo', 'analysis', 'for', 'ancient', 'historical', 'places']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'geo', 'analysis', 'ancient', 'historical', 'places']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'geo', 'analysis', 'ancient', 'historical', 'place']
# 과정1 title 원본: A Study on Deriving an Optimal Route for Foreign Tourists through the Analysis of Big Data
# 과정2 title enWords(re: 대소문자남기기): A Study on Deriving an Optimal Route for Foreign Tourists through the Analysis of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'deriving', 'an', 'optimal', 'route', 'for', 'foreign', 'tourists', 'through', 'the', 'analysis', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'deriving', 'optimal', 'route', 'foreign', 'tourists', 'analysis', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'deriving', 'optimal', 'route', 'foreign', 'tourist', 'analysis', 'big', 'data']
# 과정1 title 원본: Development Problems and Countermeasures of Rural E-Commerce Logistics in the Context of Big Data and Internet of Things
# 과정2 title enWords(re: 대소문자남기기): Development Problems and Countermeasures of Rural E Commerce Logistics in the Context of Big Data and Internet of Things
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['development', 'problems', 'and', 'countermeasures', 'of', 'rural', 'e', 'commerce', 'logistics', 'in', 'the', 'context', 'of', 'big', 'data', 'and', 'internet', 'of', 'things']
# 과정4 title enWordsTokenStop(불용어 제거): ['development', 'problems', 'countermeasures', 'rural', 'e', 'commerce', 'logistics', 'context', 'big', 'data', 'internet', 'things']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['development', 'problem', 'countermeasure', 'rural', 'e', 'commerce', 'logistics', 'context', 'big', 'data', 'internet', 'thing']
# 과정1 title 원본: ASSESSING THE IMPACT OF BIG DATA ANALYTICS ON DYNAMIC MARKETING CAPABILITIES AND PERFORMANCE IN THE FASHION INDUSTRY. PERSPECTIVES FROM EUROPEAN BUSINESSES
# 과정2 title enWords(re: 대소문자남기기): ASSESSING THE IMPACT OF BIG DATA ANALYTICS ON DYNAMIC MARKETING CAPABILITIES AND PERFORMANCE IN THE FASHION INDUSTRY PERSPECTIVES FROM EUROPEAN BUSINESSES
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['assessing', 'the', 'impact', 'of', 'big', 'data', 'analytics', 'on', 'dynamic', 'marketing', 'capabilities', 'and', 'performance', 'in', 'the', 'fashion', 'industry', 'perspectives', 'from', 'european', 'businesses']
# 과정4 title enWordsTokenStop(불용어 제거): ['assessing', 'impact', 'big', 'data', 'analytics', 'dynamic', 'marketing', 'capabilities', 'performance', 'fashion', 'industry', 'perspectives', 'european', 'businesses']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['assessing', 'impact', 'big', 'data', 'analytics', 'dynamic', 'marketing', 'capability', 'performance', 'fashion', 'industry', 'perspective', 'european', 'business']
# 과정1 title 원본: 빅데이터를(Big Data)를 활용한 교통정책에 관한 연구: 서울시 심야(올빼미)버스 중심으로
# 과정2 title enWords(re: 대소문자남기기):  Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data']
# 과정1 title 원본: HOW TIME MODERATES THE RELATIONSHIP BETWEEN BIG DATA ANALYTICS USE AND COMPANY PERFORMANCE
# 과정2 title enWords(re: 대소문자남기기): HOW TIME MODERATES THE RELATIONSHIP BETWEEN BIG DATA ANALYTICS USE AND COMPANY PERFORMANCE
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['how', 'time', 'moderates', 'the', 'relationship', 'between', 'big', 'data', 'analytics', 'use', 'and', 'company', 'performance']
# 과정4 title enWordsTokenStop(불용어 제거): ['time', 'moderates', 'relationship', 'big', 'data', 'analytics', 'use', 'company', 'performance']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['time', 'moderate', 'relationship', 'big', 'data', 'analytics', 'use', 'company', 'performance']
# 과정1 title 원본: Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis']
# 과정1 title 원본: A Meta-Analysis on the Metabolic Syndrome Risk Factors using Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): A Meta Analysis on the Metabolic Syndrome Risk Factors using Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'meta', 'analysis', 'on', 'the', 'metabolic', 'syndrome', 'risk', 'factors', 'using', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['meta', 'analysis', 'metabolic', 'syndrome', 'risk', 'factors', 'using', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['meta', 'analysis', 'metabolic', 'syndrome', 'risk', 'factor', 'using', 'big', 'data', 'analysis']
# 과정1 title 원본: LEVERAGING BIG DATA AND ARTIFICIAL INTELLIGENCE FOR SERVICE INNOVATION IN MARKETING
# 과정2 title enWords(re: 대소문자남기기): LEVERAGING BIG DATA AND ARTIFICIAL INTELLIGENCE FOR SERVICE INNOVATION IN MARKETING
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['leveraging', 'big', 'data', 'and', 'artificial', 'intelligence', 'for', 'service', 'innovation', 'in', 'marketing']
# 과정4 title enWordsTokenStop(불용어 제거): ['leveraging', 'big', 'data', 'artificial', 'intelligence', 'service', 'innovation', 'marketing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['leveraging', 'big', 'data', 'artificial', 'intelligence', 'service', 'innovation', 'marketing']
# 과정1 title 원본: Analysis of the supportive care needs of the parents of preterm children in South Korea using big data text-mining: Topic modeling
# 과정2 title enWords(re: 대소문자남기기): Analysis of the supportive care needs of the parents of preterm children in South Korea using big data text mining Topic modeling
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['analysis', 'of', 'the', 'supportive', 'care', 'needs', 'of', 'the', 'parents', 'of', 'preterm', 'children', 'in', 'south', 'korea', 'using', 'big', 'data', 'text', 'mining', 'topic', 'modeling']
# 과정4 title enWordsTokenStop(불용어 제거): ['analysis', 'supportive', 'care', 'needs', 'parents', 'preterm', 'children', 'south', 'korea', 'using', 'big', 'data', 'text', 'mining', 'topic', 'modeling']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analysis', 'supportive', 'care', 'need', 'parent', 'preterm', 'child', 'south', 'korea', 'using', 'big', 'data', 'text', 'mining', 'topic', 'modeling']
# 과정1 title 원본: BIG DATA SHOWS A NEGATIVITY BIAS IN THE PERCEIVED HELPFULNESS OF ONLINE REVIEWS
# 과정2 title enWords(re: 대소문자남기기): BIG DATA SHOWS A NEGATIVITY BIAS IN THE PERCEIVED HELPFULNESS OF ONLINE REVIEWS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'shows', 'a', 'negativity', 'bias', 'in', 'the', 'perceived', 'helpfulness', 'of', 'online', 'reviews']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'shows', 'negativity', 'bias', 'perceived', 'helpfulness', 'online', 'reviews']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'show', 'negativity', 'bias', 'perceived', 'helpfulness', 'online', 'review']
# 과정1 title 원본: Trend Analysis of Terrorist Attacks in India and Pakistan Based on Big Data and Geographic Analysis
# 과정2 title enWords(re: 대소문자남기기): Trend Analysis of Terrorist Attacks in India and Pakistan Based on Big Data and Geographic Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['trend', 'analysis', 'of', 'terrorist', 'attacks', 'in', 'india', 'and', 'pakistan', 'based', 'on', 'big', 'data', 'and', 'geographic', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['trend', 'analysis', 'terrorist', 'attacks', 'india', 'pakistan', 'based', 'big', 'data', 'geographic', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['trend', 'analysis', 'terrorist', 'attack', 'india', 'pakistan', 'based', 'big', 'data', 'geographic', 'analysis']
# 과정1 title 원본: Narrative Review of the Use and Validation of Big Data Analysis Technology in the Sports Science Field
# 과정2 title enWords(re: 대소문자남기기): Narrative Review of the Use and Validation of Big Data Analysis Technology in the Sports Science Field
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['narrative', 'review', 'of', 'the', 'use', 'and', 'validation', 'of', 'big', 'data', 'analysis', 'technology', 'in', 'the', 'sports', 'science', 'field']
# 과정4 title enWordsTokenStop(불용어 제거): ['narrative', 'review', 'use', 'validation', 'big', 'data', 'analysis', 'technology', 'sports', 'science', 'field']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['narrative', 'review', 'use', 'validation', 'big', 'data', 'analysis', 'technology', 'sport', 'science', 'field']
# 과정1 title 원본: Case Study for Big Data Business using Data from Kakao Mobility Services
# 과정2 title enWords(re: 대소문자남기기): Case Study for Big Data Business using Data from Kakao Mobility Services
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['case', 'study', 'for', 'big', 'data', 'business', 'using', 'data', 'from', 'kakao', 'mobility', 'services']
# 과정4 title enWordsTokenStop(불용어 제거): ['case', 'study', 'big', 'data', 'business', 'using', 'data', 'kakao', 'mobility', 'services']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['case', 'study', 'big', 'data', 'business', 'using', 'data', 'kakao', 'mobility', 'service']
# 과정1 title 원본: 미래 성장동력 ICT의 세 가지 분야 : IoT, Wearable Device, Big Data - 제3편 : Big Data, 관찰과 데이터를 기반으로 분석하라
# 과정2 title enWords(re: 대소문자남기기):  ICT IoT Wearable Device Big Data Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['ict', 'iot', 'wearable', 'device', 'big', 'data', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['ict', 'iot', 'wearable', 'device', 'big', 'data', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['ict', 'iot', 'wearable', 'device', 'big', 'data', 'big', 'data']
# 과정1 title 원본: Big Data and Environmental Health: Application of Big Data in Air Pollution Epidemiology Research
# 과정2 title enWords(re: 대소문자남기기): Big Data and Environmental Health Application of Big Data in Air Pollution Epidemiology Research
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'environmental', 'health', 'application', 'of', 'big', 'data', 'in', 'air', 'pollution', 'epidemiology', 'research']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'environmental', 'health', 'application', 'big', 'data', 'air', 'pollution', 'epidemiology', 'research']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'environmental', 'health', 'application', 'big', 'data', 'air', 'pollution', 'epidemiology', 'research']
# 과정1 title 원본: A Study on the Financial Management Model of Business Group in the Era of Big Data
# 과정2 title enWords(re: 대소문자남기기): A Study on the Financial Management Model of Business Group in the Era of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'the', 'financial', 'management', 'model', 'of', 'business', 'group', 'in', 'the', 'era', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'financial', 'management', 'model', 'business', 'group', 'era', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'financial', 'management', 'model', 'business', 'group', 'era', 'big', 'data']
# 과정1 title 원본: A Study on Predicting the Risk of Metabolic Syndrome  according to Lifestyle through Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): A Study on Predicting the Risk of Metabolic Syndrome according to Lifestyle through Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'predicting', 'the', 'risk', 'of', 'metabolic', 'syndrome', 'according', 'to', 'lifestyle', 'through', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'predicting', 'risk', 'metabolic', 'syndrome', 'according', 'lifestyle', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'predicting', 'risk', 'metabolic', 'syndrome', 'according', 'lifestyle', 'big', 'data', 'analysis']
# 과정1 title 원본: Bankruptcy Prediction Modeling Using Market Sentiment Derived from Big Data Analytics
# 과정2 title enWords(re: 대소문자남기기): Bankruptcy Prediction Modeling Using Market Sentiment Derived from Big Data Analytics
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['bankruptcy', 'prediction', 'modeling', 'using', 'market', 'sentiment', 'derived', 'from', 'big', 'data', 'analytics']
# 과정4 title enWordsTokenStop(불용어 제거): ['bankruptcy', 'prediction', 'modeling', 'using', 'market', 'sentiment', 'derived', 'big', 'data', 'analytics']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['bankruptcy', 'prediction', 'modeling', 'using', 'market', 'sentiment', 'derived', 'big', 'data', 'analytics']
# 과정1 title 원본: A Big Data Analysis of A Hot Political Issue
# 과정2 title enWords(re: 대소문자남기기): A Big Data Analysis of A Hot Political Issue
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'analysis', 'of', 'a', 'hot', 'political', 'issue']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'hot', 'political', 'issue']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'hot', 'political', 'issue']
# 과정1 title 원본: The Big Data Analytics Regarding the Cadastral Resurvey News Articles
# 과정2 title enWords(re: 대소문자남기기): The Big Data Analytics Regarding the Cadastral Resurvey News Articles
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'big', 'data', 'analytics', 'regarding', 'the', 'cadastral', 'resurvey', 'news', 'articles']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'regarding', 'cadastral', 'resurvey', 'news', 'articles']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'regarding', 'cadastral', 'resurvey', 'news', 'article']
# 과정1 title 원본: Big Data Analysis of Genes Associated With Neuropsychiatric Disorders in an Alzheimer’s Disease Animal Model
# 과정2 title enWords(re: 대소문자남기기): Big Data Analysis of Genes Associated With Neuropsychiatric Disorders in an Alzheimer s Disease Animal Model
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis', 'of', 'genes', 'associated', 'with', 'neuropsychiatric', 'disorders', 'in', 'an', 'alzheimer', 's', 'disease', 'animal', 'model']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'genes', 'associated', 'neuropsychiatric', 'disorders', 'alzheimer', 'disease', 'animal', 'model']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'gene', 'associated', 'neuropsychiatric', 'disorder', 'alzheimer', 'disease', 'animal', 'model']
# 과정1 title 원본: Big data differential analysis of microglial cell responses in neurodegenerative diseases
# 과정2 title enWords(re: 대소문자남기기): Big data differential analysis of microglial cell responses in neurodegenerative diseases
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'differential', 'analysis', 'of', 'microglial', 'cell', 'responses', 'in', 'neurodegenerative', 'diseases']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'differential', 'analysis', 'microglial', 'cell', 'responses', 'neurodegenerative', 'diseases']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'differential', 'analysis', 'microglial', 'cell', 'response', 'neurodegenerative', 'disease']
# 과정1 title 원본: Big Data Processing with MapReduce for E-Book
# 과정2 title enWords(re: 대소문자남기기): Big Data Processing with MapReduce for E Book
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'processing', 'with', 'mapreduce', 'for', 'e', 'book']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'processing', 'mapreduce', 'e', 'book']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'processing', 'mapreduce', 'e', 'book']
# 과정1 title 원본: A Study on Exploring Direction for Future Education for the Common Good Based on Big Data
# 과정2 title enWords(re: 대소문자남기기): A Study on Exploring Direction for Future Education for the Common Good Based on Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'exploring', 'direction', 'for', 'future', 'education', 'for', 'the', 'common', 'good', 'based', 'on', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'exploring', 'direction', 'future', 'education', 'common', 'good', 'based', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'exploring', 'direction', 'future', 'education', 'common', 'good', 'based', 'big', 'data']
# 과정1 title 원본: Big Data Analytics : From Data to Insight
# 과정2 title enWords(re: 대소문자남기기): Big Data Analytics From Data to Insight
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analytics', 'from', 'data', 'to', 'insight']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'data', 'insight']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'data', 'insight']
# 과정1 title 원본: Building an Analytical Platform of Big Data for Quality Inspection = 식품업종 제조 생산 에너지 최적화를 위한 빅데이터 플랫폼 개발
# 과정2 title enWords(re: 대소문자남기기): Building an Analytical Platform of Big Data for Quality Inspection
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['building', 'an', 'analytical', 'platform', 'of', 'big', 'data', 'for', 'quality', 'inspection']
# 과정4 title enWordsTokenStop(불용어 제거): ['building', 'analytical', 'platform', 'big', 'data', 'quality', 'inspection']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['building', 'analytical', 'platform', 'big', 'data', 'quality', 'inspection']
# 과정1 title 원본: Research on Predicting the Mental Health of College Students with Prediction Models based on Big Data Technology
# 과정2 title enWords(re: 대소문자남기기): Research on Predicting the Mental Health of College Students with Prediction Models based on Big Data Technology
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['research', 'on', 'predicting', 'the', 'mental', 'health', 'of', 'college', 'students', 'with', 'prediction', 'models', 'based', 'on', 'big', 'data', 'technology']
# 과정4 title enWordsTokenStop(불용어 제거): ['research', 'predicting', 'mental', 'health', 'college', 'students', 'prediction', 'models', 'based', 'big', 'data', 'technology']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['research', 'predicting', 'mental', 'health', 'college', 'student', 'prediction', 'model', 'based', 'big', 'data', 'technology']
# 과정1 title 원본: Implementation of Big Data Analysis System for EMS
# 과정2 title enWords(re: 대소문자남기기): Implementation of Big Data Analysis System for EMS
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['implementation', 'of', 'big', 'data', 'analysis', 'system', 'for', 'ems']
# 과정4 title enWordsTokenStop(불용어 제거): ['implementation', 'big', 'data', 'analysis', 'system', 'ems']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['implementation', 'big', 'data', 'analysis', 'system', 'em']
# 과정1 title 원본: Logical Analysis of Customized Cosmetics Using Big Data Based on Clinical Testing
# 과정2 title enWords(re: 대소문자남기기): Logical Analysis of Customized Cosmetics Using Big Data Based on Clinical Testing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['logical', 'analysis', 'of', 'customized', 'cosmetics', 'using', 'big', 'data', 'based', 'on', 'clinical', 'testing']
# 과정4 title enWordsTokenStop(불용어 제거): ['logical', 'analysis', 'customized', 'cosmetics', 'using', 'big', 'data', 'based', 'clinical', 'testing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['logical', 'analysis', 'customized', 'cosmetic', 'using', 'big', 'data', 'based', 'clinical', 'testing']
# 과정1 title 원본: Big Data Research in the Field of Endocrine Diseases Using the Korean National Health Information Database
# 과정2 title enWords(re: 대소문자남기기): Big Data Research in the Field of Endocrine Diseases Using the Korean National Health Information Database
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'research', 'in', 'the', 'field', 'of', 'endocrine', 'diseases', 'using', 'the', 'korean', 'national', 'health', 'information', 'database']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'research', 'field', 'endocrine', 'diseases', 'using', 'korean', 'national', 'health', 'information', 'database']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'research', 'field', 'endocrine', 'disease', 'using', 'korean', 'national', 'health', 'information', 'database']
# 과정1 title 원본: Tourism Planning Platform Based on Big Data = 基于大&amp;#25968;据的旅游&amp;#35745;&amp;#21010;制定平台&amp;#30740;究
# 과정2 title enWords(re: 대소문자남기기): Tourism Planning Platform Based on Big Data amp amp amp amp
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['tourism', 'planning', 'platform', 'based', 'on', 'big', 'data', 'amp', 'amp', 'amp', 'amp']
# 과정4 title enWordsTokenStop(불용어 제거): ['tourism', 'planning', 'platform', 'based', 'big', 'data', 'amp', 'amp', 'amp', 'amp']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['tourism', 'planning', 'platform', 'based', 'big', 'data', 'amp', 'amp', 'amp', 'amp']
# 과정1 title 원본: An Empirical Study on the Influencing Factors for Big Data Intented Adoption : Focusing on the Strategic Value Recognition and TOE Framework
# 과정2 title enWords(re: 대소문자남기기): An Empirical Study on the Influencing Factors for Big Data Intented Adoption Focusing on the Strategic Value Recognition and TOE Framework
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['an', 'empirical', 'study', 'on', 'the', 'influencing', 'factors', 'for', 'big', 'data', 'intented', 'adoption', 'focusing', 'on', 'the', 'strategic', 'value', 'recognition', 'and', 'toe', 'framework']
# 과정4 title enWordsTokenStop(불용어 제거): ['empirical', 'study', 'influencing', 'factors', 'big', 'data', 'intented', 'adoption', 'focusing', 'strategic', 'value', 'recognition', 'toe', 'framework']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['empirical', 'study', 'influencing', 'factor', 'big', 'data', 'intented', 'adoption', 'focusing', 'strategic', 'value', 'recognition', 'toe', 'framework']
# 과정1 title 원본: Utilization of Big Data Analytics to Personalize Online Brand Experiences : A Case Study of A Popular Online Shopping Brand in South Korea
# 과정2 title enWords(re: 대소문자남기기): Utilization of Big Data Analytics to Personalize Online Brand Experiences A Case Study of A Popular Online Shopping Brand in South Korea
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['utilization', 'of', 'big', 'data', 'analytics', 'to', 'personalize', 'online', 'brand', 'experiences', 'a', 'case', 'study', 'of', 'a', 'popular', 'online', 'shopping', 'brand', 'in', 'south', 'korea']
# 과정4 title enWordsTokenStop(불용어 제거): ['utilization', 'big', 'data', 'analytics', 'personalize', 'online', 'brand', 'experiences', 'case', 'study', 'popular', 'online', 'shopping', 'brand', 'south', 'korea']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['utilization', 'big', 'data', 'analytics', 'personalize', 'online', 'brand', 'experience', 'case', 'study', 'popular', 'online', 'shopping', 'brand', 'south', 'korea']
# 과정1 title 원본: An Analysis of MapReduce Framework for Big Data Processing
# 과정2 title enWords(re: 대소문자남기기): An Analysis of MapReduce Framework for Big Data Processing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['an', 'analysis', 'of', 'mapreduce', 'framework', 'for', 'big', 'data', 'processing']
# 과정4 title enWordsTokenStop(불용어 제거): ['analysis', 'mapreduce', 'framework', 'big', 'data', 'processing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analysis', 'mapreduce', 'framework', 'big', 'data', 'processing']
# 과정1 title 원본: 빅데이터(Big Data) 기술의 동향과 군 적용시 고려사항
# 과정2 title enWords(re: 대소문자남기기):  Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data']
# 과정1 title 원본: Modeling Method for Classification of Piano Music Style based on Big Data Mining and Machine Learning
# 과정2 title enWords(re: 대소문자남기기): Modeling Method for Classification of Piano Music Style based on Big Data Mining and Machine Learning
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['modeling', 'method', 'for', 'classification', 'of', 'piano', 'music', 'style', 'based', 'on', 'big', 'data', 'mining', 'and', 'machine', 'learning']
# 과정4 title enWordsTokenStop(불용어 제거): ['modeling', 'method', 'classification', 'piano', 'music', 'style', 'based', 'big', 'data', 'mining', 'machine', 'learning']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['modeling', 'method', 'classification', 'piano', 'music', 'style', 'based', 'big', 'data', 'mining', 'machine', 'learning']
# 과정1 title 원본: A Study on Deriving an Optimal Route for Foreign Tourists through the Analysis of Big Data
# 과정2 title enWords(re: 대소문자남기기): A Study on Deriving an Optimal Route for Foreign Tourists through the Analysis of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'deriving', 'an', 'optimal', 'route', 'for', 'foreign', 'tourists', 'through', 'the', 'analysis', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'deriving', 'optimal', 'route', 'foreign', 'tourists', 'analysis', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'deriving', 'optimal', 'route', 'foreign', 'tourist', 'analysis', 'big', 'data']
# 과정1 title 원본: A Meta-Analysis of Influencing Dietary Interventions on the Metabolic Syndrome Risk Factors Utilizing Big Data
# 과정2 title enWords(re: 대소문자남기기): A Meta Analysis of Influencing Dietary Interventions on the Metabolic Syndrome Risk Factors Utilizing Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'meta', 'analysis', 'of', 'influencing', 'dietary', 'interventions', 'on', 'the', 'metabolic', 'syndrome', 'risk', 'factors', 'utilizing', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['meta', 'analysis', 'influencing', 'dietary', 'interventions', 'metabolic', 'syndrome', 'risk', 'factors', 'utilizing', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['meta', 'analysis', 'influencing', 'dietary', 'intervention', 'metabolic', 'syndrome', 'risk', 'factor', 'utilizing', 'big', 'data']
# 과정1 title 원본: Effective Usage of Big Data for Governments’ Content Services
# 과정2 title enWords(re: 대소문자남기기): Effective Usage of Big Data for Governments Content Services
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['effective', 'usage', 'of', 'big', 'data', 'for', 'governments', 'content', 'services']
# 과정4 title enWordsTokenStop(불용어 제거): ['effective', 'usage', 'big', 'data', 'governments', 'content', 'services']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['effective', 'usage', 'big', 'data', 'government', 'content', 'service']
# 과정1 title 원본: Finding Industries for Big Data Usage on the Basis of AHP
# 과정2 title enWords(re: 대소문자남기기): Finding Industries for Big Data Usage on the Basis of AHP
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['finding', 'industries', 'for', 'big', 'data', 'usage', 'on', 'the', 'basis', 'of', 'ahp']
# 과정4 title enWordsTokenStop(불용어 제거): ['finding', 'industries', 'big', 'data', 'usage', 'basis', 'ahp']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['finding', 'industry', 'big', 'data', 'usage', 'basis', 'ahp']
# 과정1 title 원본: Big Data and Policy Directions for Korean Service Firms
# 과정2 title enWords(re: 대소문자남기기): Big Data and Policy Directions for Korean Service Firms
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'and', 'policy', 'directions', 'for', 'korean', 'service', 'firms']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'policy', 'directions', 'korean', 'service', 'firms']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'policy', 'direction', 'korean', 'service', 'firm']
# 과정1 title 원본: The Big Data Platform for Satellite Remote Sensing Data
# 과정2 title enWords(re: 대소문자남기기): The Big Data Platform for Satellite Remote Sensing Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'big', 'data', 'platform', 'for', 'satellite', 'remote', 'sensing', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'platform', 'satellite', 'remote', 'sensing', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'platform', 'satellite', 'remote', 'sensing', 'data']
# 과정1 title 원본: The Meaning of Economic Activity of Middle-aged Men using Big Data
# 과정2 title enWords(re: 대소문자남기기): The Meaning of Economic Activity of Middle aged Men using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'meaning', 'of', 'economic', 'activity', 'of', 'middle', 'aged', 'men', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['meaning', 'economic', 'activity', 'middle', 'aged', 'men', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['meaning', 'economic', 'activity', 'middle', 'aged', 'men', 'using', 'big', 'data']
# 과정1 title 원본: A Big Data Study on Viewers’ Response and Success Factors in the D2C Era Focused on tvN’s Web-real Variety ‘SinSeoYuGi’ and Naver TV Cast Programming
# 과정2 title enWords(re: 대소문자남기기): A Big Data Study on Viewers Response and Success Factors in the D C Era Focused on tvN s Web real Variety SinSeoYuGi and Naver TV Cast Programming
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'study', 'on', 'viewers', 'response', 'and', 'success', 'factors', 'in', 'the', 'd', 'c', 'era', 'focused', 'on', 'tvn', 's', 'web', 'real', 'variety', 'sinseoyugi', 'and', 'naver', 'tv', 'cast', 'programming']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'viewers', 'response', 'success', 'factors', 'c', 'era', 'focused', 'tvn', 'web', 'real', 'variety', 'sinseoyugi', 'naver', 'tv', 'cast', 'programming']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'viewer', 'response', 'success', 'factor', 'c', 'era', 'focused', 'tvn', 'web', 'real', 'variety', 'sinseoyugi', 'naver', 'tv', 'cast', 'programming']
# 과정1 title 원본: Load Balancing for Distributed Processing of Real-time Spatial Big Data Stream
# 과정2 title enWords(re: 대소문자남기기): Load Balancing for Distributed Processing of Real time Spatial Big Data Stream
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['load', 'balancing', 'for', 'distributed', 'processing', 'of', 'real', 'time', 'spatial', 'big', 'data', 'stream']
# 과정4 title enWordsTokenStop(불용어 제거): ['load', 'balancing', 'distributed', 'processing', 'real', 'time', 'spatial', 'big', 'data', 'stream']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['load', 'balancing', 'distributed', 'processing', 'real', 'time', 'spatial', 'big', 'data', 'stream']
# 과정1 title 원본: Healthcare Big Data for Pharmacovigilance and Safety Evaluation of Pharmaceutical Products
# 과정2 title enWords(re: 대소문자남기기): Healthcare Big Data for Pharmacovigilance and Safety Evaluation of Pharmaceutical Products
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['healthcare', 'big', 'data', 'for', 'pharmacovigilance', 'and', 'safety', 'evaluation', 'of', 'pharmaceutical', 'products']
# 과정4 title enWordsTokenStop(불용어 제거): ['healthcare', 'big', 'data', 'pharmacovigilance', 'safety', 'evaluation', 'pharmaceutical', 'products']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['healthcare', 'big', 'data', 'pharmacovigilance', 'safety', 'evaluation', 'pharmaceutical', 'product']
# 과정1 title 원본: Design of Health Warning Model on the Basis of CRM by use of Health Big Data = 의료 빅데이터를 활용한 CRM 기반 건강예보모형 설계
# 과정2 title enWords(re: 대소문자남기기): Design of Health Warning Model on the Basis of CRM by use of Health Big Data CRM
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['design', 'of', 'health', 'warning', 'model', 'on', 'the', 'basis', 'of', 'crm', 'by', 'use', 'of', 'health', 'big', 'data', 'crm']
# 과정4 title enWordsTokenStop(불용어 제거): ['design', 'health', 'warning', 'model', 'basis', 'crm', 'use', 'health', 'big', 'data', 'crm']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['design', 'health', 'warning', 'model', 'basis', 'crm', 'use', 'health', 'big', 'data', 'crm']
# 과정1 title 원본: ISO/IEC 9126 Quality Model-based Assessment Criteria for Measuring the Quality of Big Data Analysis Platform
# 과정2 title enWords(re: 대소문자남기기): ISO IEC Quality Model based Assessment Criteria for Measuring the Quality of Big Data Analysis Platform
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['iso', 'iec', 'quality', 'model', 'based', 'assessment', 'criteria', 'for', 'measuring', 'the', 'quality', 'of', 'big', 'data', 'analysis', 'platform']
# 과정4 title enWordsTokenStop(불용어 제거): ['iso', 'iec', 'quality', 'model', 'based', 'assessment', 'criteria', 'measuring', 'quality', 'big', 'data', 'analysis', 'platform']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['iso', 'iec', 'quality', 'model', 'based', 'assessment', 'criterion', 'measuring', 'quality', 'big', 'data', 'analysis', 'platform']
# 과정1 title 원본: A Big Data Analysis of Public Interest in Defense Reform 2.0 and Suggestions for Policy Completion
# 과정2 title enWords(re: 대소문자남기기): A Big Data Analysis of Public Interest in Defense Reform and Suggestions for Policy Completion
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'analysis', 'of', 'public', 'interest', 'in', 'defense', 'reform', 'and', 'suggestions', 'for', 'policy', 'completion']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'public', 'interest', 'defense', 'reform', 'suggestions', 'policy', 'completion']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'public', 'interest', 'defense', 'reform', 'suggestion', 'policy', 'completion']
# 과정1 title 원본: A Benchmark Test of Spatial Big Data Processing Tools and a MapReduce Application
# 과정2 title enWords(re: 대소문자남기기): A Benchmark Test of Spatial Big Data Processing Tools and a MapReduce Application
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'benchmark', 'test', 'of', 'spatial', 'big', 'data', 'processing', 'tools', 'and', 'a', 'mapreduce', 'application']
# 과정4 title enWordsTokenStop(불용어 제거): ['benchmark', 'test', 'spatial', 'big', 'data', 'processing', 'tools', 'mapreduce', 'application']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['benchmark', 'test', 'spatial', 'big', 'data', 'processing', 'tool', 'mapreduce', 'application']
# 과정1 title 원본: Addressing Big Data solution enabled Connected Vehicle services using Hadoop = Hadoop을 이용한 스마트 자동차 서비스용 빅 데이터 솔루션 개발
# 과정2 title enWords(re: 대소문자남기기): Addressing Big Data solution enabled Connected Vehicle services using Hadoop Hadoop
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['addressing', 'big', 'data', 'solution', 'enabled', 'connected', 'vehicle', 'services', 'using', 'hadoop', 'hadoop']
# 과정4 title enWordsTokenStop(불용어 제거): ['addressing', 'big', 'data', 'solution', 'enabled', 'connected', 'vehicle', 'services', 'using', 'hadoop', 'hadoop']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['addressing', 'big', 'data', 'solution', 'enabled', 'connected', 'vehicle', 'service', 'using', 'hadoop', 'hadoop']
# 과정1 title 원본: 치안분야에서의 Big Data 활용 사례와 바람직한 공공 연구조직 설계
# 과정2 title enWords(re: 대소문자남기기):  Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data']
# 과정1 title 원본: Study of Future Flow in Arctic Transportation using Big Data
# 과정2 title enWords(re: 대소문자남기기): Study of Future Flow in Arctic Transportation using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['study', 'of', 'future', 'flow', 'in', 'arctic', 'transportation', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'future', 'flow', 'arctic', 'transportation', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'future', 'flow', 'arctic', 'transportation', 'using', 'big', 'data']
# 과정1 title 원본: Keyword Analysis of COVID-19 in News Big Data : Focused on 4 Major Daily Newspapers
# 과정2 title enWords(re: 대소문자남기기): Keyword Analysis of COVID in News Big Data Focused on Major Daily Newspapers
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['keyword', 'analysis', 'of', 'covid', 'in', 'news', 'big', 'data', 'focused', 'on', 'major', 'daily', 'newspapers']
# 과정4 title enWordsTokenStop(불용어 제거): ['keyword', 'analysis', 'covid', 'news', 'big', 'data', 'focused', 'major', 'daily', 'newspapers']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['keyword', 'analysis', 'covid', 'news', 'big', 'data', 'focused', 'major', 'daily', 'newspaper']
# 과정1 title 원본: A Big Data Study on Viewers' Response and Success Factors in the D2C Era Focused on tvN's Web-real Variety 'SinSeoYuGi' and Naver TV Cast Programming
# 과정2 title enWords(re: 대소문자남기기): A Big Data Study on Viewers Response and Success Factors in the D C Era Focused on tvN s Web real Variety SinSeoYuGi and Naver TV Cast Programming
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'study', 'on', 'viewers', 'response', 'and', 'success', 'factors', 'in', 'the', 'd', 'c', 'era', 'focused', 'on', 'tvn', 's', 'web', 'real', 'variety', 'sinseoyugi', 'and', 'naver', 'tv', 'cast', 'programming']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'viewers', 'response', 'success', 'factors', 'c', 'era', 'focused', 'tvn', 'web', 'real', 'variety', 'sinseoyugi', 'naver', 'tv', 'cast', 'programming']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'viewer', 'response', 'success', 'factor', 'c', 'era', 'focused', 'tvn', 'web', 'real', 'variety', 'sinseoyugi', 'naver', 'tv', 'cast', 'programming']
# 과정1 title 원본: 보건의료 Big Data 현황 및 활용도 전망
# 과정2 title enWords(re: 대소문자남기기):  Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data']
# 과정1 title 원본: The role of satisfaction on customer reuse to airline services: An application of Big Data approaches
# 과정2 title enWords(re: 대소문자남기기): The role of satisfaction on customer reuse to airline services An application of Big Data approaches
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'role', 'of', 'satisfaction', 'on', 'customer', 'reuse', 'to', 'airline', 'services', 'an', 'application', 'of', 'big', 'data', 'approaches']
# 과정4 title enWordsTokenStop(불용어 제거): ['role', 'satisfaction', 'customer', 'reuse', 'airline', 'services', 'application', 'big', 'data', 'approaches']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['role', 'satisfaction', 'customer', 'reuse', 'airline', 'service', 'application', 'big', 'data', 'approach']
# 과정1 title 원본: Grid-based Big Data Classification for Mixed Data with Categorical and Numerical Attributes
# 과정2 title enWords(re: 대소문자남기기): Grid based Big Data Classification for Mixed Data with Categorical and Numerical Attributes
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['grid', 'based', 'big', 'data', 'classification', 'for', 'mixed', 'data', 'with', 'categorical', 'and', 'numerical', 'attributes']
# 과정4 title enWordsTokenStop(불용어 제거): ['grid', 'based', 'big', 'data', 'classification', 'mixed', 'data', 'categorical', 'numerical', 'attributes']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['grid', 'based', 'big', 'data', 'classification', 'mixed', 'data', 'categorical', 'numerical', 'attribute']
# 과정1 title 원본: Determinants of Satisfaction by Leisure Tourists from Big Data Analysis: Focused on Tourists Who Go Fishing
# 과정2 title enWords(re: 대소문자남기기): Determinants of Satisfaction by Leisure Tourists from Big Data Analysis Focused on Tourists Who Go Fishing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['determinants', 'of', 'satisfaction', 'by', 'leisure', 'tourists', 'from', 'big', 'data', 'analysis', 'focused', 'on', 'tourists', 'who', 'go', 'fishing']
# 과정4 title enWordsTokenStop(불용어 제거): ['determinants', 'satisfaction', 'leisure', 'tourists', 'big', 'data', 'analysis', 'focused', 'tourists', 'go', 'fishing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['determinant', 'satisfaction', 'leisure', 'tourist', 'big', 'data', 'analysis', 'focused', 'tourist', 'go', 'fishing']
# 과정1 title 원본: Analysis of Practical Sharing City via Big Data about Shared Bike in Seoul City
# 과정2 title enWords(re: 대소문자남기기): Analysis of Practical Sharing City via Big Data about Shared Bike in Seoul City
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['analysis', 'of', 'practical', 'sharing', 'city', 'via', 'big', 'data', 'about', 'shared', 'bike', 'in', 'seoul', 'city']
# 과정4 title enWordsTokenStop(불용어 제거): ['analysis', 'practical', 'sharing', 'city', 'via', 'big', 'data', 'shared', 'bike', 'seoul', 'city']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analysis', 'practical', 'sharing', 'city', 'via', 'big', 'data', 'shared', 'bike', 'seoul', 'city']
# 과정1 title 원본: A Study on SmartGrid Security Monitoring Based on Big Data Platform
# 과정2 title enWords(re: 대소문자남기기): A Study on SmartGrid Security Monitoring Based on Big Data Platform
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'smartgrid', 'security', 'monitoring', 'based', 'on', 'big', 'data', 'platform']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'smartgrid', 'security', 'monitoring', 'based', 'big', 'data', 'platform']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'smartgrid', 'security', 'monitoring', 'based', 'big', 'data', 'platform']
# 과정1 title 원본: Redundant Data Removal Technique for Efficient Big Data Search Processing
# 과정2 title enWords(re: 대소문자남기기): Redundant Data Removal Technique for Efficient Big Data Search Processing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['redundant', 'data', 'removal', 'technique', 'for', 'efficient', 'big', 'data', 'search', 'processing']
# 과정4 title enWordsTokenStop(불용어 제거): ['redundant', 'data', 'removal', 'technique', 'efficient', 'big', 'data', 'search', 'processing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['redundant', 'data', 'removal', 'technique', 'efficient', 'big', 'data', 'search', 'processing']
# 과정1 title 원본: Global Big Data Analysis Exploring the Determinants of Application Ratings: Evidence from the Google Play Store
# 과정2 title enWords(re: 대소문자남기기): Global Big Data Analysis Exploring the Determinants of Application Ratings Evidence from the Google Play Store
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['global', 'big', 'data', 'analysis', 'exploring', 'the', 'determinants', 'of', 'application', 'ratings', 'evidence', 'from', 'the', 'google', 'play', 'store']
# 과정4 title enWordsTokenStop(불용어 제거): ['global', 'big', 'data', 'analysis', 'exploring', 'determinants', 'application', 'ratings', 'evidence', 'google', 'play', 'store']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['global', 'big', 'data', 'analysis', 'exploring', 'determinant', 'application', 'rating', 'evidence', 'google', 'play', 'store']
# 과정1 title 원본: An Analysis on the Driving Factors of Population Changes in Local Provinces : Clues from News Big Data Analytics and Evidence from Empirical Analysis
# 과정2 title enWords(re: 대소문자남기기): An Analysis on the Driving Factors of Population Changes in Local Provinces Clues from News Big Data Analytics and Evidence from Empirical Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['an', 'analysis', 'on', 'the', 'driving', 'factors', 'of', 'population', 'changes', 'in', 'local', 'provinces', 'clues', 'from', 'news', 'big', 'data', 'analytics', 'and', 'evidence', 'from', 'empirical', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['analysis', 'driving', 'factors', 'population', 'changes', 'local', 'provinces', 'clues', 'news', 'big', 'data', 'analytics', 'evidence', 'empirical', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analysis', 'driving', 'factor', 'population', 'change', 'local', 'province', 'clue', 'news', 'big', 'data', 'analytics', 'evidence', 'empirical', 'analysis']
# 과정1 title 원본: Efficient Multimedia Data File Management and Retrieval Strategy on Big Data Processing System
# 과정2 title enWords(re: 대소문자남기기): Efficient Multimedia Data File Management and Retrieval Strategy on Big Data Processing System
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['efficient', 'multimedia', 'data', 'file', 'management', 'and', 'retrieval', 'strategy', 'on', 'big', 'data', 'processing', 'system']
# 과정4 title enWordsTokenStop(불용어 제거): ['efficient', 'multimedia', 'data', 'file', 'management', 'retrieval', 'strategy', 'big', 'data', 'processing', 'system']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['efficient', 'multimedia', 'data', 'file', 'management', 'retrieval', 'strategy', 'big', 'data', 'processing', 'system']
# 과정1 title 원본: [특집 원고] ‘빅데이터 기술 및 응용특집’: Big data tools: Focus on Challenges and Mahout
# 과정2 title enWords(re: 대소문자남기기):  Big data tools Focus on Challenges and Mahout
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'tools', 'focus', 'on', 'challenges', 'and', 'mahout']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'tools', 'focus', 'challenges', 'mahout']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'tool', 'focus', 'challenge', 'mahout']
# 과정1 title 원본: Test Study of Emotional Characteristics of Fashion Brands Based on Big Data Text Analysis = 기계학습을 이용한 게임경기의 승률 예측-MMORPG Tera: 리카노르 투기장을 중심으로
# 과정2 title enWords(re: 대소문자남기기): Test Study of Emotional Characteristics of Fashion Brands Based on Big Data Text Analysis MMORPG Tera
# ...
# 과정2 title enWords(re: 대소문자남기기): Big Data analysis of cultural relationship Focusing on Korea China cultural exchange from the governance perspective Big Data analysis of cultural relationship Focusing on Korea China cultural exchange from the governance perspective
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis', 'of', 'cultural', 'relationship', 'focusing', 'on', 'korea', 'china', 'cultural', 'exchange', 'from', 'the', 'governance', 'perspective', 'big', 'data', 'analysis', 'of', 'cultural', 'relationship', 'focusing', 'on', 'korea', 'china', 'cultural', 'exchange', 'from', 'the', 'governance', 'perspective']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'cultural', 'relationship', 'focusing', 'korea', 'china', 'cultural', 'exchange', 'governance', 'perspective', 'big', 'data', 'analysis', 'cultural', 'relationship', 'focusing', 'korea', 'china', 'cultural', 'exchange', 'governance', 'perspective']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'cultural', 'relationship', 'focusing', 'korea', 'china', 'cultural', 'exchange', 'governance', 'perspective', 'big', 'data', 'analysis', 'cultural', 'relationship', 'focusing', 'korea', 'china', 'cultural', 'exchange', 'governance', 'perspective']
# 과정1 title 원본: 빅데이터(Big data) 기술 적용 시스템 감리 점검방안 = A Study on Auditing Method of Big Data Technology Applied System
# 과정2 title enWords(re: 대소문자남기기):  Big data A Study on Auditing Method of Big Data Technology Applied System
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'study', 'on', 'auditing', 'method', 'of', 'big', 'data', 'technology', 'applied', 'system']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'auditing', 'method', 'big', 'data', 'technology', 'applied', 'system']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'auditing', 'method', 'big', 'data', 'technology', 'applied', 'system']
# 과정1 title 원본: Advanced Big Data Analysis, Artificial Intelligence & Communication Systems = Advanced Big Data Analysis, Artificial Intelligence &amp; Communication Systems
# 과정2 title enWords(re: 대소문자남기기): Advanced Big Data Analysis Artificial Intelligence Communication Systems Advanced Big Data Analysis Artificial Intelligence amp Communication Systems
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'communication', 'systems', 'advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'amp', 'communication', 'systems']
# 과정4 title enWordsTokenStop(불용어 제거): ['advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'communication', 'systems', 'advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'amp', 'communication', 'systems']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'communication', 'system', 'advanced', 'big', 'data', 'analysis', 'artificial', 'intelligence', 'amp', 'communication', 'system']
# 과정1 title 원본: Google Trends를 활용한 태권도관련 빅데이터(Big Data) 분석 = Analysis of Big Data related in Taekwondo through Google Trends
# 과정2 title enWords(re: 대소문자남기기): Google Trends Big Data Analysis of Big Data related in Taekwondo through Google Trends
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['google', 'trends', 'big', 'data', 'analysis', 'of', 'big', 'data', 'related', 'in', 'taekwondo', 'through', 'google', 'trends']
# 과정4 title enWordsTokenStop(불용어 제거): ['google', 'trends', 'big', 'data', 'analysis', 'big', 'data', 'related', 'taekwondo', 'google', 'trends']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['google', 'trend', 'big', 'data', 'analysis', 'big', 'data', 'related', 'taekwondo', 'google', 'trend']
# 과정1 title 원본: 보안에 의거한 데이터(BIG DATA)의 효과적인 이용방법 = Effective use of the method of data (BIG DATA) based on the security
# 과정2 title enWords(re: 대소문자남기기):  BIG DATA Effective use of the method of data BIG DATA based on the security
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'effective', 'use', 'of', 'the', 'method', 'of', 'data', 'big', 'data', 'based', 'on', 'the', 'security']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'effective', 'use', 'method', 'data', 'big', 'data', 'based', 'security']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'effective', 'use', 'method', 'data', 'big', 'data', 'based', 'security']
# 과정1 title 원본: Applying a sensor energy supply communication scheme to big data opportunistic networks = Applying a sensor energy supply communication scheme to big data opportunistic networks
# 과정2 title enWords(re: 대소문자남기기): Applying a sensor energy supply communication scheme to big data opportunistic networks Applying a sensor energy supply communication scheme to big data opportunistic networks
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['applying', 'a', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'to', 'big', 'data', 'opportunistic', 'networks', 'applying', 'a', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'to', 'big', 'data', 'opportunistic', 'networks']
# 과정4 title enWordsTokenStop(불용어 제거): ['applying', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'big', 'data', 'opportunistic', 'networks', 'applying', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'big', 'data', 'opportunistic', 'networks']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['applying', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'big', 'data', 'opportunistic', 'network', 'applying', 'sensor', 'energy', 'supply', 'communication', 'scheme', 'big', 'data', 'opportunistic', 'network']
# 과정1 title 원본: Identifying the Effect of Product Types in the Relationships Between Product Discounts and Consumer Distrust levels in China’s Online Social Commerce Market at the Era of Big Data = Identifying the Effect of Product Types in the Relationships Between Product Discounts and Consumer Distrust levels in China’s Online Social Commerce Market at the Era of Big Data
# 과정2 title enWords(re: 대소문자남기기): Identifying the Effect of Product Types in the Relationships Between Product Discounts and Consumer Distrust levels in China s Online Social Commerce Market at the Era of Big Data Identifying the Effect of Product Types in the Relationships Between Product Discounts and Consumer Distrust levels in China s Online Social Commerce Market at the Era of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['identifying', 'the', 'effect', 'of', 'product', 'types', 'in', 'the', 'relationships', 'between', 'product', 'discounts', 'and', 'consumer', 'distrust', 'levels', 'in', 'china', 's', 'online', 'social', 'commerce', 'market', 'at', 'the', 'era', 'of', 'big', 'data', 'identifying', 'the', 'effect', 'of', 'product', 'types', 'in', 'the', 'relationships', 'between', 'product', 'discounts', 'and', 'consumer', 'distrust', 'levels', 'in', 'china', 's', 'online', 'social', 'commerce', 'market', 'at', 'the', 'era', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['identifying', 'effect', 'product', 'types', 'relationships', 'product', 'discounts', 'consumer', 'distrust', 'levels', 'china', 'online', 'social', 'commerce', 'market', 'era', 'big', 'data', 'identifying', 'effect', 'product', 'types', 'relationships', 'product', 'discounts', 'consumer', 'distrust', 'levels', 'china', 'online', 'social', 'commerce', 'market', 'era', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['identifying', 'effect', 'product', 'type', 'relationship', 'product', 'discount', 'consumer', 'distrust', 'level', 'china', 'online', 'social', 'commerce', 'market', 'era', 'big', 'data', 'identifying', 'effect', 'product', 'type', 'relationship', 'product', 'discount', 'consumer', 'distrust', 'level', 'china', 'online', 'social', 'commerce', 'market', 'era', 'big', 'data']
# 과정1 title 원본: Informatics in emergency medicine -Big Data & Emergency Medicine : Big Data Global Trends = Informatics in emergency medicine -Big Data &amp; Emergency Medicine : Big Data Global Trends
# 과정2 title enWords(re: 대소문자남기기): Informatics in emergency medicine Big Data Emergency Medicine Big Data Global Trends Informatics in emergency medicine Big Data amp Emergency Medicine Big Data Global Trends
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['informatics', 'in', 'emergency', 'medicine', 'big', 'data', 'emergency', 'medicine', 'big', 'data', 'global', 'trends', 'informatics', 'in', 'emergency', 'medicine', 'big', 'data', 'amp', 'emergency', 'medicine', 'big', 'data', 'global', 'trends']
# 과정4 title enWordsTokenStop(불용어 제거): ['informatics', 'emergency', 'medicine', 'big', 'data', 'emergency', 'medicine', 'big', 'data', 'global', 'trends', 'informatics', 'emergency', 'medicine', 'big', 'data', 'amp', 'emergency', 'medicine', 'big', 'data', 'global', 'trends']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['informatics', 'emergency', 'medicine', 'big', 'data', 'emergency', 'medicine', 'big', 'data', 'global', 'trend', 'informatics', 'emergency', 'medicine', 'big', 'data', 'amp', 'emergency', 'medicine', 'big', 'data', 'global', 'trend']
# 과정1 title 원본: Modulation of senoinflammation by calorie restriction based on biochemical and Omics big data analysis = Modulation of senoinflammation by calorie restriction based on biochemical and Omics big data analysis
# 과정2 title enWords(re: 대소문자남기기): Modulation of senoinflammation by calorie restriction based on biochemical and Omics big data analysis Modulation of senoinflammation by calorie restriction based on biochemical and Omics big data analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['modulation', 'of', 'senoinflammation', 'by', 'calorie', 'restriction', 'based', 'on', 'biochemical', 'and', 'omics', 'big', 'data', 'analysis', 'modulation', 'of', 'senoinflammation', 'by', 'calorie', 'restriction', 'based', 'on', 'biochemical', 'and', 'omics', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['modulation', 'senoinflammation', 'calorie', 'restriction', 'based', 'biochemical', 'omics', 'big', 'data', 'analysis', 'modulation', 'senoinflammation', 'calorie', 'restriction', 'based', 'biochemical', 'omics', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['modulation', 'senoinflammation', 'calorie', 'restriction', 'based', 'biochemical', 'omics', 'big', 'data', 'analysis', 'modulation', 'senoinflammation', 'calorie', 'restriction', 'based', 'biochemical', 'omics', 'big', 'data', 'analysis']
# 과정1 title 원본: Developing an Intrusion Detection Framework for High-Speed Big Data Networks: A Comprehensive Approach = Developing an Intrusion Detection Framework for High-Speed Big Data Networks: A Comprehensive Approach
# 과정2 title enWords(re: 대소문자남기기): Developing an Intrusion Detection Framework for High Speed Big Data Networks A Comprehensive Approach Developing an Intrusion Detection Framework for High Speed Big Data Networks A Comprehensive Approach
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['developing', 'an', 'intrusion', 'detection', 'framework', 'for', 'high', 'speed', 'big', 'data', 'networks', 'a', 'comprehensive', 'approach', 'developing', 'an', 'intrusion', 'detection', 'framework', 'for', 'high', 'speed', 'big', 'data', 'networks', 'a', 'comprehensive', 'approach']
# 과정4 title enWordsTokenStop(불용어 제거): ['developing', 'intrusion', 'detection', 'framework', 'high', 'speed', 'big', 'data', 'networks', 'comprehensive', 'approach', 'developing', 'intrusion', 'detection', 'framework', 'high', 'speed', 'big', 'data', 'networks', 'comprehensive', 'approach']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['developing', 'intrusion', 'detection', 'framework', 'high', 'speed', 'big', 'data', 'network', 'comprehensive', 'approach', 'developing', 'intrusion', 'detection', 'framework', 'high', 'speed', 'big', 'data', 'network', 'comprehensive', 'approach']
# words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : [['big', 'data', 'analysis', 'r', 'studio', 'radioactive', 'waste', 'concentration', 'behavior', 'according', 'data', 'component'], ['big', 'data', 'mining'], ['development', 'big', 'data', 'platform', 'operation', 'management', 'system', 'considering', 'hpc', 'environment'], ['word', 'cloud', 'visualization', 'semantics', 'using', 'big', 'data', 'analytics', 'tool'], ['big', 'data', 'management', 'system', 'biomedical', 'image', 'improve', 'short', 'term', 'long', 'term', 'storage'], ['big', 'data', 'geo', 'analysis', 'ancient', 'historical', 'place'], ['study', 'deriving', 'optimal', 'route', 'foreign', 'tourist', 'analysis', 'big', 'data'], ['development', 'problem', 'countermeasure', 'rural', 'e', 'commerce', 'logistics', 'context', 'big', 'data', 'internet', 'thing'], ['assessing', 'impact', 'big', 'data', 'analytics', 'dynamic', 'marketing', 'capability', 'performance', 'fashion', 'industry', 'perspective', 'european', 'business'], ['big', 'data'], ['time', 'moderate', 'relationship', 'big', 'data', 'analytics', 'use', 'company', 'performance'], ['big', 'data', 'analysis'], ['meta', 'analysis', 'metabolic', 'syndrome', 'risk', 'factor', 'using', 'big', 'data', 'analysis'], ['leveraging', 'big', 'data', 'artificial', 'intelligence', 'service', 'innovation', 'marketing'], ['analysis', 'supportive', 'care', 'need', 'parent', 'preterm', 'child', 'south', 'korea', 'using', 'big', 'data', 'text', 'mining', 'topic', 'modeling'], ['big', 'data', 'show', 'negativity', 'bias', 'perceived', 'helpfulness', 'online', 'review'], ['trend', 'analysis', 'terrorist', 'attack', 'india', 'pakistan', 'based', 'big', 'data', 'geographic', 'analysis'], ['narrative', 'review', 'use', 'validation', 'big', 'data', 'analysis', 'technology', 'sport', 'science', 'field'], ['case', 'study', 'big', 'data', 'business', 'using', 'data', 'kakao', 'mobility', 'service'], ['ict', 'iot', 'wearable', 'device', 'big', 'data', 'big', 'data'], ['big', 'data', 'environmental', 'health', 'application', 'big', 'data', 'air', 'pollution', 'epidemiology', 'research'], ['study', 'financial', 'management', 'model', 'business', 'group', 'era', 'big', 'data'], ['study', 'predicting', 'risk', 'metabolic', 'syndrome', 'according', 'lifestyle', 'big', 'data', 'analysis'], ['bankruptcy', 'prediction', 'modeling', 'using', 'market', 'sentiment', 'derived', 'big', 'data', 'analytics'], ['big', 'data', 'analysis', 'hot', 'political', 'issue'], ['big', 'data', 'analytics', 'regarding', 'cadastral', 'resurvey', 'news', 'article'], ['big', 'data', 'analysis', 'gene', 'associated', 'neuropsychiatric', 'disorder', 'alzheimer', 'disease', 'animal', 'model'], ['big', 'data', 'differential', 'analysis', 'microglial', 'cell', 'response', 'neurodegenerative', 'disease'], ['big', 'data', 'processing', 'mapreduce', 'e', 'book'], ['study', 'exploring', 'direction', 'future', 'education', 'common', 'good', 'based', 'big', 'data'], ['big', 'data', 'analytics', 'data', 'insight'], ['building', 'analytical', 'platform', 'big', 'data', 'quality', 'inspection'], ['research', 'predicting', 'mental', 'health', 'college', 'student', 'prediction', 'model', 'based', 'big', 'data', 'technology'], ['implementation', 'big', 'data', 'analysis', 'system', 'em'], ['logical', 'analysis', 'customized', 'cosmetic', 'using', 'big', 'data', 'based', 'clinical', 'testing'], ['big', 'data', 'research', 'field', 'endocrine', 'disease', 'using', 'korean', 'national', 'health', 'information', 'database'], ['tourism', 'planning', 'platform', 'based', 'big', 'data', 'amp', 'amp', 'amp', 'amp'], ['empirical', 'study', 'influencing', 'factor', 'big', 'data', 'intented', 'adoption', 'focusing', 'strategic', 'value', 'recognition', 'toe', 'framework'], ['utilization', 'big', 'data', 'analytics', 'personalize', 'online', 'brand', 'experience', 'case', 'study', 'popular', 'online', 'shopping', 'brand', 'south', 'korea'], ['analysis', 'mapreduce', 'framework', 'big', 'data',  ...

# %%
# 2차원 리스트 -> 1차원 리스트 , 차원 축소 
# reduce 함수 이용하기. 차원 축소 
# list 함수 이용해서, 1차원 리스트로 만들기. 
result = reduce(lambda x,y : x+y, words)
words2 = list(result)
#result
print(f"result 타입 조사 : {type(words2)}")
print(f"words2 : {words2}")
# Out:
# result 타입 조사 : <class 'list'>
# words2 : ['big', 'data', 'analysis', 'r', 'studio', 'radioactive', 'waste', 'concentration', 'behavior', 'according', 'data', 'component', 'big', 'data', 'mining', 'development', 'big', 'data', 'platform', 'operation', 'management', 'system', 'considering', 'hpc', 'environment', 'word', 'cloud', 'visualization', 'semantics', 'using', 'big', 'data', 'analytics', 'tool', 'big', 'data', 'management', 'system', 'biomedical', 'image', 'improve', 'short', 'term', 'long', 'term', 'storage', 'big', 'data', 'geo', 'analysis', 'ancient', 'historical', 'place', 'study', 'deriving', 'optimal', 'route', 'foreign', 'tourist', 'analysis', 'big', 'data', 'development', 'problem', 'countermeasure', 'rural', 'e', 'commerce', 'logistics', 'context', 'big', 'data', 'internet', 'thing', 'assessing', 'impact', 'big', 'data', 'analytics', 'dynamic', 'marketing', 'capability', 'performance', 'fashion', 'industry', 'perspective', 'european', 'business', 'big', 'data', 'time', 'moderate', 'relationship', 'big', 'data', 'analytics', 'use', 'company', 'performance', 'big', 'data', 'analysis', 'meta', 'analysis', 'metabolic', 'syndrome', 'risk', 'factor', 'using', 'big', 'data', 'analysis', 'leveraging', 'big', 'data', 'artificial', 'intelligence', 'service', 'innovation', 'marketing', 'analysis', 'supportive', 'care', 'need', 'parent', 'preterm', 'child', 'south', 'korea', 'using', 'big', 'data', 'text', 'mining', 'topic', 'modeling', 'big', 'data', 'show', 'negativity', 'bias', 'perceived', 'helpfulness', 'online', 'review', 'trend', 'analysis', 'terrorist', 'attack', 'india', 'pakistan', 'based', 'big', 'data', 'geographic', 'analysis', 'narrative', 'review', 'use', 'validation', 'big', 'data', 'analysis', 'technology', 'sport', 'science', 'field', 'case', 'study', 'big', 'data', 'business', 'using', 'data', 'kakao', 'mobility', 'service', 'ict', 'iot', 'wearable', 'device', 'big', 'data', 'big', 'data', 'big', 'data', 'environmental', 'health', 'application', 'big', 'data', 'air', 'pollution', 'epidemiology', 'research', 'study', 'financial', 'management', 'model', 'business', 'group', 'era', 'big', 'data', 'study', 'predicting', 'risk', 'metabolic', 'syndrome', 'according', 'lifestyle', 'big', 'data', 'analysis', 'bankruptcy', 'prediction', 'modeling', 'using', 'market', 'sentiment', 'derived', 'big', 'data', 'analytics', 'big', 'data', 'analysis', 'hot', 'political', 'issue', 'big', 'data', 'analytics', 'regarding', 'cadastral', 'resurvey', 'news', 'article', 'big', 'data', 'analysis', 'gene', 'associated', 'neuropsychiatric', 'disorder', 'alzheimer', 'disease', 'animal', 'model', 'big', 'data', 'differential', 'analysis', 'microglial', 'cell', 'response', 'neurodegenerative', 'disease', 'big', 'data', 'processing', 'mapreduce', 'e', 'book', 'study', 'exploring', 'direction', 'future', 'education', 'common', 'good', 'based', 'big', 'data', 'big', 'data', 'analytics', 'data', 'insight', 'building', 'analytical', 'platform', 'big', 'data', 'quality', 'inspection', 'research', 'predicting', 'mental', 'health', 'college', 'student', 'prediction', 'model', 'based', 'big', 'data', 'technology', 'implementation', 'big', 'data', 'analysis', 'system', 'em', 'logical', 'analysis', 'customized', 'cosmetic', 'using', 'big', 'data', 'based', 'clinical', 'testing', 'big', 'data', 'research', 'field', 'endocrine', 'disease', 'using', 'korean', 'national', 'health', 'information', 'database', 'tourism', 'planning', 'platform', 'based', 'big', 'data', 'amp', 'amp', 'amp', 'amp', 'empirical', 'study', 'influencing', 'factor', 'big', 'data', 'intented', 'adoption', 'focusing', 'strategic', 'value', 'recognition', 'toe', 'framework', 'utilization', 'big', 'data', 'analytics', 'personalize', 'online', 'brand', 'experience', 'case', 'study', 'popular', 'online', 'shopping', 'brand', 'south', 'korea', 'analysis', 'mapreduce', 'framework', 'big', 'data', 'processing', 'big', 'data', 'modeling', 'method', 'classification', 'piano', 'music', 'style', 'based', 'big', 'data',  ...

# %%
# 데이터 탐색, 기본 분석 모델 만들기. 
# Counter -> 해당 단어 빈도 집계 해주는 함수. 
count = Counter(words2)
count
# Out:
# Counter({'data': 1243,
#          'big': 1158,
#          'analysis': 366,
#          'based': 227,
#          'using': 209,
#          'study': 184,
#          'system': 98,
#          'social': 79,
#          'research': 78,
#          'analytics': 77,
#          'model': 61,
#          'korea': 60,
#          'application': 60,
#          'management': 52,
#          'service': 49,
#          'development': 48,
#          'platform': 42,
#          'information': 42,
#          'network': 42,
#          'smart': 42,
#          'industry': 40,
#          'environment': 38,
#          'trend': 38,
#          'cloud': 37,
#          'health': 37,
#          'processing': 37,
#          'medium': 36,
#          'technology': 35,
#          'prediction': 35,
#          'factor': 34,
#          'mining': 33,
#          'learning': 33,
#          'design': 33,
#          'case': 32,
#          'korean': 32,
#          'ai': 32,
#          'era': 31,
#          'method': 31,
#          'intelligence': 30,
#          'framework': 29,
#          'healthcare': 29,
#          'use': 28,
#          'strategy': 28,
#          'future': 27,
#          'perception': 27,
#          'performance': 26,
#          'technique': 26,
#          'tourism': 25,
#          'business': 24,
#          'focusing': 24,
#          'utilization': 24,
#          'approach': 24,
#          'policy': 23,
#          'city': 23,
#          'computing': 23,
#          'artificial': 22,
#          'security': 22,
#          'process': 22,
#          'detection': 22,
#          'marketing': 21,
#          'iot': 21,
#          'value': 21,
#          'public': 21,
#          'medical': 21,
#          'time': 20,
#          'machine': 20,
#          'evaluation': 20,
#          'customer': 20,
#          'challenge': 20,
#          'china': 20,
#          'real': 19,
#          'personal': 19,
#          'modeling': 18,
#          'change': 18,
#          'impact': 17,
#          'review': 17,
#          'market': 17,
#          'spatial': 17,
#          'covid': 17,
#          'decision': 17,
#          'energy': 16,
#          'consumption': 16,
#          'communication': 16,
#          'tourist': 15,
#          'south': 15,
#          'online': 15,
#          'financial': 15,
#          'quality': 15,
#          'focused': 15,
#          'hadoop': 15,
#          'manufacturing': 15,
#          'emergency': 15,
#          'privacy': 15,
#          'medicine': 15,
#          'driven': 15,
#          'risk': 14,
#          'care': 14,
#          'sport': 14,
#          'education': 14,
#          'implementation': 14,
#          'database': 14,
#          'product': 14,
#          'protection': 14,
#          'pattern': 14,
#          'problem': 13,
#          'relationship': 13,
#          'company': 13,
#          'direction': 13,
#          'classification': 13,
#          'efficient': 13,
#          'digital': 13,
#          'cancer': 13,
#          'consumer': 13,
#          'effect': 13,
#          'visualization': 12,
#          'dynamic': 12,
#          'disease': 12,
#          'building': 12,
#          'utilizing': 12,
#          'assessment': 12,
#          'keyword': 12,
#          'comparative': 12,
#          'new': 12,
#          'algorithm': 12,
#          'food': 12,
#          'making': 12,
#          'deep': 12,
#          'storage': 11,
#          'meta': 11,
#          'amp': 11,
#          'usage': 11,
#          'web': 11,
#          'google': 11,
#          'scheme': 11,
#          'spark': 11,
#          'integration': 11,
#          'construction': 11,
#          'traffic': 11,
#          'mobile': 11,
#          'recommendation': 11,
#          'tool': 10,
#          'perspective': 10,
#          'text': 10,
#          'news': 10,
#          'mapreduce': 10,
#          'national': 10,
#          'activity': 10,
#          'sharing': 10,
#          'evidence': 10,
#          'insurance': 10,
#          'project': 10,
#          'age': 10,
#          'multi': 10,
#          'r': 9,
#          'e': 9,
#          'internet': 9,
#          'fashion': 9,
#          'syndrome': 9,
#          'issue': 9,
#          'exploring': 9,
#          'brand': 9,
#          'vehicle': 9,
#          'global': 9,
#          'estimation': 9,
#          'comparison': 9,
#          'legal': 9,
#          'power': 9,
#          'optimization': 9,
#          'stock': 9,
#          'factory': 9,
#          'commerce': 8,
#          'metabolic': 8,
#          'environmental': 8,
#          'air': 8,
#          'predicting': 8,
#          'government': 8,
#          'characteristic': 8,
#          'semantic': 8,
#          'status': 8,
#          'game': 8,
#          'current': 8,
#          'urban': 8,
#          'analyzing': 8,
#          'collection': 8,
#          'architecture': 8,
#          'knowledge': 8,
#          'creation': 8,
#          'structure': 8,
#          'survey': 8,
#          'type': 8,
#          'start': 8,
#          'matter': 8,
#          'incidence': 8,
#          'advanced': 8,
#          'intention': 8,
#          'cultural': 8,
#          'user': 8,
#          'weather': 8,
#          'chinese': 8,
#          'prospect': 8,
#          'image': 7,
#          'term': 7,
#          'geo': 7,
#          'foreign': 7,
#          'context': 7,
#          'thing': 7,
#          'capability': 7,
#          'need': 7,
#          'ict': 7,
#          'sentiment': 7,
#          'response': 7,
#          'effective': 7,
#          'content': 7,
#          'distributed': 7,
#          'satisfaction': 7,
#          'search': 7,
#          'focus': 7,
#          'hotel': 7,
#          'large': 7,
#          'rate': 7,
#          'clustering': 7,
#          'related': 7,
#          'center': 7,
#          'map': 7,
#          'high': 7,
#          'human': 7,
#          'university': 7,
#          'multiple': 7,
#          'prevention': 7,
#          'generation': 7,
#          'sustainable': 7,
#          'library': 7,
#          'developing': 7,
#          'support': 7,
#          'plan': 7,
#          'forecasting': 7,
#          'implication': 7,
#          'industrial': 7,
#          'predict': 7,
#          'small': 7,
#          'supply': 7,
#          'chain': 7,
#          'event': 7,
#          'intrusion': 7,
#          'restaurant': 7,
#          'waste': 6,
#          'behavior': 6,
#          'historical': 6,
#          'countermeasure': 6,
#          'innovation': 6,
#          'child': 6,
#          'field': 6,
#          'group': 6,
#          'political': 6,
#          'college': 6,
#          'influencing': 6,
#          'adoption': 6,
#          'finding': 6,
#          'ahp': 6,
#          'firm': 6,
#          'economic': 6,
#          'c': 6,
#          'stream': 6,
#          'connected': 6,
#          'major': 6,
#          'role': 6,
#          'seoul': 6,
#          'monitoring': 6,
#          'extraction': 6,
#          'selection': 6,
#          'enterprise': 6,
#          'evaluating': 6,
#          'ecosystem': 6,
#          'apache': 6,
#          'python': 6,
#          'open': 6,
#          'investment': 6,
#          'crisis': 6,
#          'sector': 6,
#          'toward': 6,
#          'international': 6,
#          'cost': 6,
#          'unstructured': 6,
#          'index': 6,
#          'analytic': 6,
#          'area': 6,
#          'patient': 6,
#          'sn': 6,
#          'production': 6,
#          'agriculture': 6,
#          'condition': 6,
#          'improve': 5,
#          'leveraging': 5,
#          'topic': 5,
#          'insight': 5,
#          'analytical': 5,
#          'student': 5,
#          'cosmetic': 5,
#          'empirical': 5,
#          'experience': 5,
#          'solution': 5,
#          'flow': 5,
#          'bike': 5,
#          'population': 5,
#          'retrieval': 5,
#          'example': 5,
#          'k': 5,
#          'blockchain': 5,
#          'advertising': 5,
#          'towards': 5,
#          'applying': 5,
#          'regional': 5,
#          'institution': 5,
#          'resource': 5,
#          'mechanism': 5,
#          'solving': 5,
#          'registry': 5,
#          'query': 5,
#          'integrated': 5,
#          'saudi': 5,
#          'enhanced': 5,
#          'film': 5,
#          'collaboration': 5,
#          'crime': 5,
#          'concept': 5,
#          'cluster': 5,
#          'scale': 5,
#          'methodology': 5,
#          'tree': 5,
#          'different': 5,
#          'language': 5,
#          'post': 5,
#          'yield': 5,
#          'apos': 5,
#          'low': 5,
#          'lesson': 5,
#          'opinion': 5,
#          'acute': 5,
#          'sized': 5,
#          'speed': 5,
#          'inference': 5,
#          'analyze': 5,
#          'opportunity': 5,
#          'improvement': 5,
#          'automatic': 5,
#          'comprehensive': 5,
#          'biomedical': 4,
#          'optimal': 4,
#          'logistics': 4,
#          'science': 4,
#          'article': 4,
#          'customized': 4,
#          'planning': 4,
#          'basis': 4,
#          'middle': 4,
#          'viewer': 4,
#          'tv': 4,
#          'safety': 4,
#          'enabled': 4,
#          'determinant': 4,
#          'practical': 4,
#          'via': 4,
#          'driving': 4,
#          'multimedia': 4,
#          'file': 4,
#          'pollutant': 4,
#          'evolution': 4,
#          'influence': 4,
#          'location': 4,
#          'feasibility': 4,
#          'proposal': 4,
#          'key': 4,
#          'regulation': 4,
#          'implementing': 4,
#          'residential': 4,
#          'collecting': 4,
#          'agricultural': 4,
#          'background': 4,
#          'hyper': 4,
#          'statistical': 4,
#          'sensitivity': 4,
#          'source': 4,
#          'feature': 4,
#          'world': 4,
#          'culture': 4,
#          'employment': 4,
#          'governance': 4,
#          'stroke': 4,
#          'wavelet': 4,
#          'histogram': 4,
#          'awareness': 4,
#          'qualitative': 4,
#          'franchise': 4,
#          'injury': 4,
#          'dtg': 4,
#          'fuel': 4,
#          'hybrid': 4,
#          'heterogeneous': 4,
#          'next': 4,
#          'competitive': 4,
#          'cross': 4,
#          'practice': 4,
#          'distribution': 4,
#          'growth': 4,
#          'pandemic': 4,
#          'demand': 4,
#          'home': 4,
#          'sale': 4,
#          'fuzzy': 4,
#          'private': 4,
#          'activation': 4,
#          'diabetes': 4,
#          'efficiency': 4,
#          'code': 4,
#          'soil': 4,
#          'four': 4,
#          'ontology': 4,
#          'fertility': 4,
#          'informatics': 4,
#          'vitiligo': 4,
#          'chicago': 4,
#          'utility': 4,
#          'carbon': 4,
#          'autonomous': 4,
#          'cyber': 4,
#          'accident': 4,
#          'patent': 4,
#          'price': 4,
#          'therapy': 4,
#          'u': 4,
#          'traditional': 4,
#          'arabia': 4,
#          'dental': 4,
#          'asthma': 4,
#          'among': 4,
#          'standard': 4,
#          'rna': 4,
#          'forecast': 4,
#          'oracle': 4,
#          'coffee': 4,
#          'trading': 4,
#          'integrating': 4,
#          'ethical': 4,
#          'charging': 4,
#          'revolution': 4,
#          'society': 4,
#          'ups': 4,
#          'law': 4,
#          'optimizing': 4,
#          'forestry': 4,
#          'fishery': 4,
#          'general': 4,
#          'density': 4,
#          'fiberboard': 4,
#          'sensor': 4,
#          'noise': 4,
#          'floor': 4,
#          'channel': 4,
#          'according': 3,
#          'component': 3,
#          'operation': 3,
#          'considering': 3,
#          'word': 3,
#          'short': 3,
#          'long': 3,
#          'ancient': 3,
#          'attack': 3,
#          'mobility': 3,
#          'bankruptcy': 3,
#          'regarding': 3,
#          'animal': 3,
#          'good': 3,
#          'mental': 3,
#          'clinical': 3,
#          'recognition': 3,
#          'shopping': 3,
#          'sensing': 3,
#          'meaning': 3,
#          'success': 3,
#          'tvn': 3,
#          'variety': 3,
#          'sinseoyugi': 3,
#          'naver': 3,
#          'cast': 3,
#          'programming': 3,
#          'crm': 3,
#          'defense': 3,
#          'test': 3,
#          'transportation': 3,
#          'newspaper': 3,
#          'attribute': 3,
#          'shared': 3,
#          'rating': 3,
#          'play': 3,
#          'local': 3,
#          'emotional': 3,
#          'indexing': 3,
#          'encryption': 3,
#          'modelling': 3,
#          'base': 3,
#          'site': 3,
#          'function': 3,
#          'correlation': 3,
#          'busan': 3,
#          'radiation': 3,
#          'republic': 3,
#          'century': 3,
#          'resident': 3,
#          'trajectory': 3,
#          'api': 3,
#          'activating': 3,
#          'limitation': 3,
#          'pursuant': 3,
#          'optimized': 3,
#          'credit': 3,
#          'preference': 3,
#          'educational': 3,
#          'biology': 3,
#          'physical': 3,
#          'modern': 3,
#          'transport': 3,
#          'electric': 3,
#          'laboratory': 3,
#          'centric': 3,
#          'pre': 3,
#          'secure': 3,
#          'right': 3,
#          'score': 3,
#          'software': 3,
#          'networking': 3,
#          'computation': 3,
#          'functional': 3,
#          'log': 3,
#          'investigation': 3,
#          'accounting': 3,
#          'consideration': 3,
#          'series': 3,
#          'incremental': 3,
#          'identifying': 3,
#          'reality': 3,
#          'emerging': 3,
#          'scenario': 3,
#          'professional': 3,
#          'conceptual': 3,
#          'advantage': 3,
#          'know': 3,
#          'border': 3,
#          'disaster': 3,
#          'school': 3,
#          'adjustment': 3,
#          'statistic': 3,
#          'corona': 3,
#          'period': 3,
#          'view': 3,
#          'literature': 3,
#          'balance': 3,
#          'indonesia': 3,
#          'self': 3,
#          'scalable': 3,
#          'feedback': 3,
#          'g': 3,
#          'diagnosis': 3,
#          'ship': 3,
#          'community': 3,
#          'land': 3,
#          'autocorrelation': 3,
#          'hypertension': 3,
#          'created': 3,
#          'difference': 3,
#          'chemical': 3,
#          'water': 3,
#          'renewable': 3,
#          'return': 3,
#          'climate': 3,
#          'state': 3,
#          'welfare': 3,
#          'press': 3,
#          'dilemma': 3,
#          'paradox': 3,
#          'diplomacy': 3,
#          'electronic': 3,
#          'genetic': 3,
#          'adult': 3,
#          'socio': 3,
#          'infrastructure': 3,
#          'convergence': 3,
#          'measure': 3,
#          'citizen': 3,
#          'exchange': 3,
#          'well': 3,
#          'edge': 3,
#          'collaborative': 3,
#          'th': 3,
#          'embedded': 3,
#          'procedure': 3,
#          'english': 3,
#          'access': 3,
#          'various': 3,
#          'chronic': 3,
#          'road': 3,
#          'constructing': 3,
#          'hazardous': 3,
#          'cognition': 3,
#          'systematic': 3,
#          'regression': 3,
#          'neural': 3,
#          'nationwide': 3,
#          'job': 3,
#          'surgery': 3,
#          'volume': 3,
#          'sub': 3,
#          'qr': 3,
#          'end': 3,
#          'affecting': 3,
#          'skin': 3,
#          'dbaas': 3,
#          'quantitative': 3,
#          'reduction': 3,
#          'last': 3,
#          'memory': 3,
#          'special': 3,
#          'domestic': 3,
#          'standardization': 3,
#          'potential': 3,
#          'delivery': 3,
#          'lake': 3,
#          'organization': 3,
#          'abnormal': 3,
#          'v': 3,
#          'extract': 3,
#          'designing': 3,
#          'nuclear': 3,
#          'sequencing': 3,
#          'prevalence': 3,
#          'catering': 3,
#          'graph': 3,
#          'batch': 3,
#          'sequential': 3,
#          'character': 3,
#          'ev': 3,
#          'breast': 3,
#          'bdas': 3,
#          'line': 3,
#          'target': 3,
#          'hpc': 2,
#          'deriving': 2,
#          'route': 2,
#          'rural': 2,
#          'perceived': 2,
#          'device': 2,
#          'pollution': 2,
#          'epidemiology': 2,
#          'cadastral': 2,
#          'resurvey': 2,
#          'disorder': 2,
#          'book': 2,
#          'common': 2,
#          'inspection': 2,
#          'strategic': 2,
#          'music': 2,
#          'dietary': 2,
#          'intervention': 2,
#          'satellite': 2,
#          'remote': 2,
#          'aged': 2,
#          'men': 2,
#          'load': 2,
#          'balancing': 2,
#          'warning': 2,
#          'criterion': 2,
#          'interest': 2,
#          'suggestion': 2,
#          'daily': 2,
#          'airline': 2,
#          'grid': 2,
#          'numerical': 2,
#          'fishing': 2,
#          'removal': 2,
#          'province': 2,
#          'farm': 2,
#          'virtual': 2,
#          'jeonnam': 2,
#          'meteorological': 2,
#          'join': 2,
#          'thailand': 2,
#          'variable': 2,
#          'dose': 2,
#          'ecological': 2,
#          'sustainability': 2,
#          'fault': 2,
#          'protecting': 2,
#          'gyeonggi': 2,
#          'recent': 2,
#          'live': 2,
#          'hlm': 2,
#          'aspect': 2,
#          'consolidation': 2,
#          'identification': 2,
#          'art': 2,
#          'make': 2,
#          'economy': 2,
#          'anonymity': 2,
#          'linked': 2,
#          'claim': 2,
#          'property': 2,
#          'discovery': 2,
#          'reduce': 2,
#          'task': 2,
#          'taxonomy': 2,
#          'domain': 2,
#          'reference': 2,
#          'housing': 2,
#          'result': 2,
#          'bda': 2,
#          'forensic': 2,
#          'listed': 2,
#          'kospi': 2,
#          'provide': 2,
#          'technical': 2,
#          'aimed': 2,
#          'embezzlement': 2,
#          'aid': 2,
#          'gap': 2,
#          'achieve': 2,
#          'floral': 2,
#          'gi': 2,
#          'bim': 2,
#          'intelligent': 2,
#          'christian': 2,
#          'civil': 2,
#          'ethic': 2,
#          'joint': 2,
#          'computer': 2,
#          'exploratory': 2,
#          'indian': 2,
#          'parliamentary': 2,
#          'predictive': 2,
#          'improving': 2,
#          'entertainment': 2,
#          'program': 2,
#          'situation': 2,
#          'authentication': 2,
#          'dairy': 2,
#          'course': 2,
#          'seosan': 2,
#          'purchasing': 2,
#          'connection': 2,
#          'smes': 2,
#          'expenditure': 2,
#          'epidemic': 2,
#          'share': 2,
#          'profiling': 2,
#          'understanding': 2,
#          'bk': 2,
#          'plus': 2,
#          'operational': 2,
#          'force': 2,
#          'cultivated': 2,
#          'coupling': 2,
#          'temporal': 2,
#          'presence': 2,
#          'pregnancy': 2,
#          'determines': 2,
#          'nhis': 2,
#          'gender': 2,
#          'affect': 2,
#          'physiological': 2,
#          'marker': 2,
#          'exercise': 2,
#          'modality': 2,
#          'anterior': 2,
#          'cruciate': 2,
#          'ligament': 2,
#          'substation': 2,
#          'pain': 2,
#          'repair': 2,
#          'message': 2,
#          'board': 2,
#          'causality': 2,
#          'climatic': 2,
#          'italian': 2,
#          'ryegrass': 2,
#          'paddy': 2,
#          'scenic': 2,
#          'take': 2,
#          'let': 2,
#          'syndromic': 2,
#          'surveillance': 2,
#          'outbreak': 2,
#          'nuc': 2,
#          'getting': 2,
#          'started': 2,
#          'ssd': 2,
#          'enhancement': 2,
#          'bio': 2,
#          'bruno': 2,
#          'j': 2,
#          'strasser': 2,
#          'experiment': 2,
#          'xv': 2,
#          'pp': 2,
#          'dictator': 2,
#          'macroeconomic': 2,
#          'poster': 2,
#          'session': 2,
#          'coverage': 2,
#          'neutrality': 2,
#          'treatment': 2,
#          'manifest': 2,
#          'psoriasis': 2,
#          'constructivism': 2,
#          'early': 2,
#          'childhood': 2,
#          'symptomatic': 2,
#          'discoid': 2,
#          'meniscus': 2,
#          'epidemiologic': 2,
#          'hira': 2,
#          'neoplasia': 2,
#          'colorectal': 2,
#          'screening': 2,
#          'asymptomatic': 2,
#          'fog': 2,
#          'trans': 2,
#          'disciplinary': 2,
#          'studying': 2,
#          'eye': 2,
#          'microfinance': 2,
#          'analyzed': 2,
#          'document': 2,
#          'incheon': 2,
#          'adaptive': 2,
#          'primary': 2,
#          'participation': 2,
#          'critical': 2,
#          'plant': 2,
#          'integrative': 2,
#          'genomic': 2,
#          'handling': 2,
#          'outlier': 2,
#          'weight': 2,
#          'particulate': 2,
#          'anomaly': 2,
#          'cnn': 2,
#          'bilstm': 2,
#          'paprika': 2,
#          'oral': 2,
#          'pcp': 2,
#          'tsk': 2,
#          'export': 2,
#          'import': 2,
#          'nowcasting': 2,
#          'ethnic': 2,
#          'overcoming': 2,
#          'twitter': 2,
#          'family': 2,
#          'landscape': 2,
#          'combination': 2,
#          'cause': 2,
#          'interaction': 2,
#          'managing': 2,
#          'meeting': 2,
#          'email': 2,
#          'vector': 2,
#          'lstm': 2,
#          'obesity': 2,
#          'audience': 2,
#          'video': 2,
#          'structured': 2,
#          'experimental': 2,
#          'transformation': 2,
#          'increased': 2,
#          'inventory': 2,
#          'beer': 2,
#          'random': 2,
#          'indoor': 2,
#          'healthy': 2,
#          'principal': 2,
#          'wellness': 2,
#          'advancing': 2,
#          'examination': 2,
#          'arrival': 2,
#          'importance': 2,
#          'corporate': 2,
#          'enhancing': 2,
#          'matching': 2,
#          'drone': 2,
#          'writing': 2,
#          'teaching': 2,
#          'one': 2,
#          'crowd': 2,
#          'examining': 2,
#          'vitalization': 2,
#          'foundation': 2,
#          'simulation': 2,
#          'oriented': 2,
#          'prior': 2,
#          'continuous': 2,
#          'iran': 2,
#          'adolescent': 2,
#          'adopting': 2,
#          'esg': 2,
#          'consulting': 2,
#          'antiplatelet': 2,
#          'concern': 2,
#          'de': 2,
#          'identified': 2,
#          'without': 2,
#          'consent': 2,
#          'occupational': 2,
#          'requirement': 2,
#          'mediating': 2,
#          'contemporary': 2,
#          'history': 2,
#          'scm': 2,
#          'training': 2,
#          'mode': 2,
#          'beyond': 2,
#          'dimensional': 2,
#          'double': 2,
#          'three': 2,
#          'round': 2,
#          'garden': 2,
#          'distancing': 2,
#          'solo': 2,
#          'traveler': 2,
#          'iomt': 2,
#          'protective': 2,
#          'achyranthes': 2,
#          'radix': 2,
#          'root': 2,
#          'cddp': 2,
#          'induced': 2,
#          'liver': 2,
#          'kidney': 2,
#          'damage': 2,
#          'sd': 2,
#          'rat': 2,
#          'nation': 2,
#          'p': 2,
#          'complex': 2,
#          'chatbot': 2,
#          'record': 2,
#          'deduction': 2,
#          'gamification': 2,
#          'keywords': 2,
#          'riding': 2,
#          'owned': 2,
#          'bad': 2,
#          'floating': 2,
#          'jeju': 2,
#          'switching': 2,
#          'bibliographic': 2,
#          'negative': 2,
#          'association': 2,
#          'reconstruction': 2,
#          'hub': 2,
#          'fourth': 2,
#          'stress': 2,
#          'micrornas': 2,
#          'carcinogenesis': 2,
#          'chemoprevention': 2,
#          'sedative': 2,
#          'ng': 2,
#          'inductive': 2,
#          'reasoning': 2,
#          'quarter': 2,
#          'mass': 2,
#          'subfields': 2,
#          'pr': 2,
#          'journalism': 2,
#          'almighty': 2,
#          'everything': 2,
#          'q': 2,
#          'sorting': 2,
#          'six': 2,
#          'sigma': 2,
#          'individualized': 2,
#          'methodological': 2,
#          'homomorphic': 2,
#          'outsourced': 2,
#          'sing': 2,
#          'amorepacific': 2,
#          'storm': 2,
#          'wsns': 2,
#          'sink': 2,
#          'soc': 2,
#          'district': 2,
#          'division': 2,
#          'poi': 2,
#          'obstructive': 2,
#          'pulmonary': 2,
#          'exacerbation': 2,
#          'focasting': 2,
#          'interpretable': 2,
#          'quot': 2,
#          'inter': 2,
#          'category': 2,
#          'north': 2,
#          'birth': 2,
#          ...})

# %%
# 임시 딕션너리 만들기. 
word_count = dict()

# 상위 50개 정도만 추출 해보기. 
for tag, counts in count.most_common(50):
  if(len(str(tag)) >1):
    word_count[tag] = counts
    print(f"tag : {tag}, counts : {counts}")

word_count
# Out:
# tag : data, counts : 1243
# tag : big, counts : 1158
# tag : analysis, counts : 366
# tag : based, counts : 227
# tag : using, counts : 209
# tag : study, counts : 184
# tag : system, counts : 98
# tag : social, counts : 79
# tag : research, counts : 78
# tag : analytics, counts : 77
# tag : model, counts : 61
# tag : korea, counts : 60
# tag : application, counts : 60
# tag : management, counts : 52
# tag : service, counts : 49
# tag : development, counts : 48
# tag : platform, counts : 42
# tag : information, counts : 42
# tag : network, counts : 42
# tag : smart, counts : 42
# tag : industry, counts : 40
# tag : environment, counts : 38
# tag : trend, counts : 38
# tag : cloud, counts : 37
# tag : health, counts : 37
# tag : processing, counts : 37
# tag : medium, counts : 36
# tag : technology, counts : 35
# tag : prediction, counts : 35
# tag : factor, counts : 34
# tag : mining, counts : 33
# tag : learning, counts : 33
# tag : design, counts : 33
# tag : case, counts : 32
# tag : korean, counts : 32
# tag : ai, counts : 32
# tag : era, counts : 31
# tag : method, counts : 31
# tag : intelligence, counts : 30
# tag : framework, counts : 29
# tag : healthcare, counts : 29
# tag : use, counts : 28
# tag : strategy, counts : 28
# tag : future, counts : 27
# tag : perception, counts : 27
# tag : performance, counts : 26
# tag : technique, counts : 26
# tag : tourism, counts : 25
# tag : business, counts : 24
# tag : focusing, counts : 24
# {'data': 1243,
#  'big': 1158,
#  'analysis': 366,
#  'based': 227,
#  'using': 209,
#  'study': 184,
#  'system': 98,
#  'social': 79,
#  'research': 78,
#  'analytics': 77,
#  'model': 61,
#  'korea': 60,
#  'application': 60,
#  'management': 52,
#  'service': 49,
#  'development': 48,
#  'platform': 42,
#  'information': 42,
#  'network': 42,
#  'smart': 42,
#  'industry': 40,
#  'environment': 38,
#  'trend': 38,
#  'cloud': 37,
#  'health': 37,
#  'processing': 37,
#  'medium': 36,
#  'technology': 35,
#  'prediction': 35,
#  'factor': 34,
#  'mining': 33,
#  'learning': 33,
#  'design': 33,
#  'case': 32,
#  'korean': 32,
#  'ai': 32,
#  'era': 31,
#  'method': 31,
#  'intelligence': 30,
#  'framework': 29,
#  'healthcare': 29,
#  'use': 28,
#  'strategy': 28,
#  'future': 27,
#  'perception': 27,
#  'performance': 26,
#  'technique': 26,
#  'tourism': 25,
#  'business': 24,
#  'focusing': 24}

# %%
# 추출된 상위 50개 단어 시각화하기. 
# 막대그래프 
# word_count : 상위 50개 단어 추출한 , 딕션너리 = Map 비슷 ,key : value 
# 기본이 : 오름 차순, reverse, 내림 차순이라고 보면 됨. 
sorted_Keys = sorted(word_count, key = word_count.get, reverse=True)

# values 추출, 내림 차순 
sorted_Values= sorted(word_count.values(), reverse=True)

# 시각화 
# x축 : range(len(word_count))
# Y축 : sorted_Values
plt.bar(range(len(word_count)),sorted_Values, align='center')
# 눈금 옵션 조정. x축 라벨 붙이기 작업. rotation 세로 방향으로 기울이기. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# 기존 데이터 프레임에 새로운 컬럼(doc_count) 추가, 임의로 0으로 값 넣기. 
all_files_data_concat["doc_count"] = 0

#  출판일 기준으로 그룹화해서, count 집계 표기 하기.
# as_index=False 옵션을 사용하면 그룹화된 결과의 "출판일"이 인덱스가 아닌 일반 열로 유지됩니다.
summary_date = all_files_data_concat.groupby("출판일", as_index=False)["doc_count"].count()
summary_date
# Out:
#      출판일  doc_count
# 0   2011          2
# 1   2012         20
# 2   2013         35
# 3   2014         54
# 4   2015         94
# 5   2016        120
# 6   2017         80
# 7   2018         81
# 8   2019        109
# 9   2020         80
# 10  2021        103
# 11  2022         66
# 12  2023         78
# 13  2024         75
# 14  2025          3

# %%
# 꺽은선 그래프 
# 가로 세로 비율
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc_count")
plt.grid(True)
# x축 : range(len(summary_date))
# y축 : summary_date["doc_count"]
plt.plot(range(len(summary_date)), summary_date["doc_count"] )
# x축 라벨링 옵션 
plt.xticks(range(len(summary_date)), [text for text in summary_date["출판일"]])
plt.show()

# %%
# 워드 클라우드 공식 문서 , 다양한 이미지 위에 처리하기. 
# https://amueller.github.io/word_cloud/index.html

# 워드 클라우드 시각화
# STOPWORDS는 WordCloud 라이브러리에서 제공하는 기본 불용어 집합입니다.
# 이 코드는 STOPWORDS를 집합(set)으로 변환하여,
# 워드 클라우드 생성 시 불필요한 단어(예: "the", "and" 등)를 제거하는 데 사용합니다.
stopwords = set(STOPWORDS)

# stopwords=stopwords:
# 위에서 정의한 불용어 집합을 사용하여, 워드 클라우드에 포함하지 않을 단어들을 지정합니다.
wc = WordCloud(background_color="ivory", stopwords=stopwords, width=800, height=600)
# word_count는 단어와 해당 단어의 빈도수를 담은 사전(dictionary)입니다.
# 이 메서드는 word_count에 저장된 단어들의 빈도 정보를 바탕으로 워드 클라우드를 생성하고, 그 결과를 cloud에 저장합니다.
cloud = wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis("off")
plt.show()
# data': 1235,
#  'big': 1113,
#  'analytics': 110,
#  'based': 102,
#  'analysis': 93,
#  'driven': 70,
#  'system': 64,
#  'using': 57,
